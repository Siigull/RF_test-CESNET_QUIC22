# %%
from cesnet_datazoo.datasets import CESNET_QUIC22
from cesnet_datazoo.config import DatasetConfig, AppSelection, ValidationApproach

dataset = CESNET_QUIC22("~/datasets/CESNET-QUIC22/", size="XS")

common_params = {
    "dataset": dataset,
    "apps_selection": AppSelection.ALL_KNOWN,
    "train_period_name": "W-2022-44",
    "val_approach": ValidationApproach.SPLIT_FROM_TRAIN,
    "train_val_split_fraction": 0.2,
    "use_packet_histograms": True,
}
dataset_config = DatasetConfig(**common_params)
dataset.set_dataset_config_and_initialize(dataset_config)
train_dataframe = dataset.get_train_df(flatten_ppi=True)
val_dataframe = dataset.get_val_df(flatten_ppi=True)
test_dataframe = dataset.get_test_df(flatten_ppi=True)
# Out:
# Loading data from dataloader
# 100%|██████████| 8162/8162 [00:08<00:00, 941.92it/s]
# Loading data from dataloader
# 100%|██████████| 192/192 [00:03<00:00, 49.67it/s]
# Loading data from dataloader
# 100%|██████████| 1247/1247 [00:08<00:00, 145.83it/s]

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import f1_score, accuracy_score

from dataclasses import dataclass
import random

from pyqlearning.q_learning import QLearning

import numpy as np

X = train_dataframe.drop(columns="APP").to_numpy()[:1000]
y = train_dataframe["APP"].to_numpy()[:1000]

X_test = test_dataframe.drop(columns="APP").to_numpy()[:100]
y_test = test_dataframe["APP"].to_numpy()[:100]

X_final_test = test_dataframe.drop(columns="APP").to_numpy()[:10000]
y_final_test = test_dataframe["APP"].to_numpy()[:10000]

class Q(QLearning):
    # last_acc = 0
    # i_not_used = set()
    # X_used = np.ndarray()
    # y_used = np.ndarray()
    # clf = RandomForestClassifier()

    def update_state(self, state_key, action_key):
        return 0

    def initialize(self, len, iters, cols):
        self.X_used = np.ndarray(shape = (iters, cols))
        self.y_used = np.ndarray(shape = (iters,))
        self.last_acc = 0
        self.clf = RandomForestClassifier()
        self.i_not_used = set(range(len))

    def extract_possible_actions(self, state_key):
        return list(self.i_not_used)
    
    def select_action(self, state_key, next_action_list):
        epsilon_greedy_flag = bool(np.random.binomial(n=1, p=self.epsilon_greedy_rate))

        if epsilon_greedy_flag is False:
            action_key = random.choice(next_action_list)
        else:
            action_key = self.predict_next_action(state_key, next_action_list)

        self.i_not_used.remove(action_key)

        return int(action_key)

    def train_clf(self):
        if self.t == 1:
            self.clf.fit(self.X_used[self.t - 1].reshape(1, -1), 
                         self.y_used[self.t - 1].ravel())
        else:
            self.clf.fit(self.X_used[:(self.t - 1)], 
                         self.y_used[:(self.t - 1)])

    def test_acc(self):
        self.train_clf()

        predict_arr = self.clf.predict(X_test)

        return f1_score(y_test, predict_arr, average='weighted')

    def observe_reward_value(self, state_key, action_key):
        self.X_used[self.t - 1] = X[action_key]
        self.y_used[self.t - 1] = y[action_key]

        cur_acc = self.test_acc()
        reward = cur_acc - self.last_acc
        self.last_acc = cur_acc

        self.save_r_df(state_key, reward)

        return reward

q = Q()
q.epsilon_greedy_rate = 0.1
q.alpha_value = 0.9
q.gamma_value = 0.9

iters = 100

for i in range(40):
    print(f"iter {i}\n")
    q.initialize(len(X), iters, X.shape[1])
    state_key = 0
    
    if i == 39:
        q.epsilon_gredy_rate = 0
        
    q.learn(state_key, iters)
    predict_arr = q.clf.predict(X_final_test)
    print(f"q_learning_acc: {accuracy_score(y_final_test, predict_arr):.4f}")

clf = RandomForestClassifier()
clf.fit(X, y)
predict_arr = clf.predict(X_final_test)
print(f"base_model_acc: {accuracy_score(y_final_test, predict_arr):.4f}")
# Out:
# iter 0
#
# q_learning_acc: 0.3174
# iter 1
#
# q_learning_acc: 0.3445
# iter 2
#
# q_learning_acc: 0.3535
# iter 3
#
# q_learning_acc: 0.3387
# iter 4
#
# q_learning_acc: 0.3206
# iter 5
#
# q_learning_acc: 0.3401
# iter 6
#
# q_learning_acc: 0.2544
# iter 7
#
# q_learning_acc: 0.3156
# iter 8
#
# q_learning_acc: 0.3581
# iter 9
#
# q_learning_acc: 0.3569
# iter 10
#
# q_learning_acc: 0.3678
# iter 11
#
# q_learning_acc: 0.3527
# iter 12
#
# q_learning_acc: 0.3698
# iter 13
#
# q_learning_acc: 0.3466
# iter 14
#
# q_learning_acc: 0.3499
# iter 15
#
# q_learning_acc: 0.3441
# iter 16
#
# q_learning_acc: 0.3669
# iter 17
#
# q_learning_acc: 0.3557
# iter 18
#
# q_learning_acc: 0.3649
# iter 19
#
# q_learning_acc: 0.3636
# iter 20
#
# q_learning_acc: 0.3684
# iter 21
#
# q_learning_acc: 0.3342
# iter 22
#
# q_learning_acc: 0.3514
# iter 23
#
# q_learning_acc: 0.3190
# iter 24
#
# q_learning_acc: 0.3384
# iter 25
#
# q_learning_acc: 0.3511
# iter 26
#
# q_learning_acc: 0.3532
# iter 27
#
# q_learning_acc: 0.3397
# iter 28
#
# q_learning_acc: 0.3581
# iter 29
#
# q_learning_acc: 0.3530
# iter 30
#
# q_learning_acc: 0.3835
# iter 31
#
# q_learning_acc: 0.3629
# iter 32
#
# q_learning_acc: 0.3468
# iter 33
#
# q_learning_acc: 0.3231
# iter 34
#
# q_learning_acc: 0.3833
# iter 35
#
# q_learning_acc: 0.3071
# iter 36
#
# q_learning_acc: 0.3672
# iter 37
#
# q_learning_acc: 0.3758
# iter 38
#
# q_learning_acc: 0.3508
# iter 39
#
# q_learning_acc: 0.3647
# iter 40
#
# q_learning_acc: 0.3533
# iter 41
#
# q_learning_acc: 0.3437
# iter 42
#
# q_learning_acc: 0.3486
# iter 43
#
# q_learning_acc: 0.3820
# iter 44
#
# q_learning_acc: 0.3768
# iter 45
#
# q_learning_acc: 0.3942
# iter 46
#
# q_learning_acc: 0.3294
# iter 47
#
# q_learning_acc: 0.3692
# iter 48
#
# q_learning_acc: 0.3456
# iter 49
#
# q_learning_acc: 0.3347
# iter 50
#
# q_learning_acc: 0.3077
# iter 51
#
# q_learning_acc: 0.3163
# iter 52
#
# q_learning_acc: 0.3151
# iter 53
#
# q_learning_acc: 0.3460
# iter 54
#
# q_learning_acc: 0.3576
# iter 55
#
# q_learning_acc: 0.3073
# iter 56
#
# q_learning_acc: 0.3541
# iter 57
#
# q_learning_acc: 0.3578
# iter 58
#
# q_learning_acc: 0.3813
# iter 59
#
# q_learning_acc: 0.3547
# iter 60
#
# q_learning_acc: 0.2801
# iter 61
#
# q_learning_acc: 0.3223
# iter 62
#
# q_learning_acc: 0.3442
# iter 63
#
# q_learning_acc: 0.3446
# iter 64
#
# q_learning_acc: 0.3325
# iter 65
#
# q_learning_acc: 0.3158
# iter 66
#
# q_learning_acc: 0.3176
# iter 67
#
# q_learning_acc: 0.3155
# iter 68
#
# q_learning_acc: 0.3686
# iter 69
#
# q_learning_acc: 0.3524
# iter 70
#
# q_learning_acc: 0.3310
# iter 71
#
# q_learning_acc: 0.3560
# iter 72
#
# q_learning_acc: 0.3240
# iter 73
#
# q_learning_acc: 0.3348
# iter 74
#
# q_learning_acc: 0.3841
# iter 75
#
# q_learning_acc: 0.3561
# iter 76
#
# q_learning_acc: 0.3237
# iter 77
#
# q_learning_acc: 0.3478
# iter 78
#
# q_learning_acc: 0.2953
# iter 79
#
# q_learning_acc: 0.3109
# iter 80
#
# q_learning_acc: 0.3361
# iter 81
#
# q_learning_acc: 0.3856
# iter 82
#
# q_learning_acc: 0.3542
# iter 83
#
# q_learning_acc: 0.3583
# iter 84
#
# q_learning_acc: 0.3167
# iter 85
#
# q_learning_acc: 0.2892
# iter 86
#
# q_learning_acc: 0.3354
# iter 87
#
# q_learning_acc: 0.3068
# iter 88
#
# q_learning_acc: 0.3241
# iter 89
#
# q_learning_acc: 0.3581
# iter 90
#
# q_learning_acc: 0.3162
# iter 91
#
# q_learning_acc: 0.3559
# iter 92
#
# q_learning_acc: 0.3731
# iter 93
#
# q_learning_acc: 0.2951
# iter 94
#
# q_learning_acc: 0.3618
# iter 95
#
# q_learning_acc: 0.3570
# iter 96
#
# q_learning_acc: 0.3457
# iter 97
#
# q_learning_acc: 0.3559
# iter 98
#
# q_learning_acc: 0.3488
# iter 99
#
# q_learning_acc: 0.3558
# iter 100
#
# q_learning_acc: 0.3461
# iter 101
#
# q_learning_acc: 0.3461
# iter 102
#
# q_learning_acc: 0.3321
# iter 103
#
# q_learning_acc: 0.3629
# iter 104
#
# q_learning_acc: 0.3522
# iter 105
#
# q_learning_acc: 0.3438
# iter 106
#
# q_learning_acc: 0.3491
# iter 107
#
# q_learning_acc: 0.3643
# iter 108
#
# q_learning_acc: 0.3559
# iter 109
#
# q_learning_acc: 0.3350
# iter 110
#
# q_learning_acc: 0.3729
# iter 111
#
# q_learning_acc: 0.3441
# iter 112
#
# q_learning_acc: 0.3296
# iter 113
#
# q_learning_acc: 0.3285
# iter 114
#
# q_learning_acc: 0.2940
# iter 115
#
# q_learning_acc: 0.3266
# iter 116
#
# q_learning_acc: 0.3131
# iter 117
#
# q_learning_acc: 0.3606
# iter 118
#
# q_learning_acc: 0.3282
# iter 119
#
# q_learning_acc: 0.3924
# iter 120
#
# q_learning_acc: 0.3573
# iter 121
#
# q_learning_acc: 0.3904
# iter 122
#
# q_learning_acc: 0.2771
# iter 123
#
# q_learning_acc: 0.3082
# iter 124
#
# q_learning_acc: 0.3621
# iter 125
#
# q_learning_acc: 0.3572
# iter 126
#
# q_learning_acc: 0.3509
# iter 127
#
# q_learning_acc: 0.3167
# iter 128
#
# q_learning_acc: 0.3394
# iter 129
#
# q_learning_acc: 0.3749
# iter 130
#
# q_learning_acc: 0.3446
# iter 131
#
# q_learning_acc: 0.3340
# iter 132
#
# q_learning_acc: 0.3756
# iter 133
#
# q_learning_acc: 0.3095
# iter 134
#
# q_learning_acc: 0.3700
# iter 135
#
# q_learning_acc: 0.3508
# iter 136
#
# q_learning_acc: 0.3107
# iter 137
#
# q_learning_acc: 0.2346
# iter 138
#
# q_learning_acc: 0.3043
# iter 139
#
# q_learning_acc: 0.3055
# iter 140
#
# q_learning_acc: 0.3642
# iter 141
#
# q_learning_acc: 0.3548
# iter 142
#
# q_learning_acc: 0.3110
# iter 143
#
# q_learning_acc: 0.3707
# iter 144
#
# q_learning_acc: 0.3396
# iter 145
#
# q_learning_acc: 0.3548
# iter 146
#
# q_learning_acc: 0.3092
# iter 147
#
# q_learning_acc: 0.3525
# iter 148
#
# q_learning_acc: 0.3020
# iter 149
#
# q_learning_acc: 0.3037
# iter 150
#
# q_learning_acc: 0.3345
# iter 151
#
# q_learning_acc: 0.3290
# iter 152
#
# q_learning_acc: 0.3629
# iter 153
#
# q_learning_acc: 0.3219
# iter 154
#
# q_learning_acc: 0.3550
# iter 155
#
# q_learning_acc: 0.3304
# iter 156
#
# q_learning_acc: 0.3530
# iter 157
#
# q_learning_acc: 0.2987
# iter 158
#
# q_learning_acc: 0.3734
# iter 159
#
# q_learning_acc: 0.3838
# iter 160
#
# q_learning_acc: 0.3127
# iter 161
#
# q_learning_acc: 0.3636
# iter 162
#
# q_learning_acc: 0.3540
# iter 163
#
# q_learning_acc: 0.2987
# iter 164
#
# q_learning_acc: 0.3628
# iter 165
#
# q_learning_acc: 0.3516
# iter 166
#
# q_learning_acc: 0.3510
# iter 167
#
# q_learning_acc: 0.2948
# iter 168
#
# q_learning_acc: 0.3845
# iter 169
#
# q_learning_acc: 0.3295
# iter 170
#
# q_learning_acc: 0.3318
# iter 171
#
# q_learning_acc: 0.3851
# iter 172
#
# q_learning_acc: 0.3651
# iter 173
#
# q_learning_acc: 0.3438
# iter 174
#
# q_learning_acc: 0.3525
# iter 175
#
# q_learning_acc: 0.3901
# iter 176
#
# q_learning_acc: 0.3943
# iter 177
#
# q_learning_acc: 0.3178
# iter 178
#
# q_learning_acc: 0.3144
# iter 179
#
# q_learning_acc: 0.3659
# iter 180
#
# q_learning_acc: 0.3268
# iter 181
#
# q_learning_acc: 0.3232
# iter 182
#
# q_learning_acc: 0.3297
# iter 183
#
# q_learning_acc: 0.3132
# iter 184
#
# q_learning_acc: 0.3318
# iter 185
#
# q_learning_acc: 0.3440
# iter 186
#
# q_learning_acc: 0.3300
# iter 187
#
# q_learning_acc: 0.3717
# iter 188
#
# q_learning_acc: 0.3928
# iter 189
#
# q_learning_acc: 0.3103
# iter 190
#
# q_learning_acc: 0.3814
# iter 191
#
# q_learning_acc: 0.3419
# iter 192
#
# q_learning_acc: 0.3730
# iter 193
#
# q_learning_acc: 0.3345
# iter 194
#
# q_learning_acc: 0.3595
# iter 195
#
# q_learning_acc: 0.3284
# iter 196
#
# q_learning_acc: 0.3212
# iter 197
#
# q_learning_acc: 0.3697
# iter 198
#
# q_learning_acc: 0.3843
# iter 199
#
# q_learning_acc: 0.3412
# base_model_acc: 0.5723

# %%
q_df = q.q_df
q_df = q_df.sort_values(by=["q_value"], ascending=False)
print(q_df)
# Out:
#     state_key  action_key   q_value
# 0          39         112  0.229820
# 0           3         210  0.223521
# 0         199         236  0.221046
# 0          25         712  0.220169
# 0         808         612  0.219948
# ..        ...         ...       ...
# 0         671         583 -0.070342
# 0         811         222 -0.070377
# 0         691         817 -0.072917
# 0         893         501 -0.074189
# 0         753         948 -0.075150
#
# [18835 rows x 3 columns]

# %%
from cesnet_datazoo.datasets import CESNET_QUIC22
from cesnet_datazoo.config import DatasetConfig, AppSelection, ValidationApproach

dataset = CESNET_QUIC22("~/datasets/CESNET-QUIC22/", size="XS")

common_params = {
    "dataset": dataset,
    "apps_selection": AppSelection.ALL_KNOWN,
    "train_period_name": "W-2022-44",
    "val_approach": ValidationApproach.SPLIT_FROM_TRAIN,
    "train_val_split_fraction": 0.2,
    "use_packet_histograms": True,
}
dataset_config = DatasetConfig(**common_params)
dataset.set_dataset_config_and_initialize(dataset_config)
train_dataframe = dataset.get_train_df(flatten_ppi=True)
val_dataframe = dataset.get_val_df(flatten_ppi=True)
test_dataframe = dataset.get_test_df(flatten_ppi=True)
# Out:
# Loading data from dataloader
# 100%|██████████| 8162/8162 [00:09<00:00, 844.36it/s]
# Loading data from dataloader
# 100%|██████████| 192/192 [00:04<00:00, 46.06it/s]
# Loading data from dataloader
# 100%|██████████| 1247/1247 [00:09<00:00, 138.19it/s]

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import f1_score, accuracy_score

from pyqlearning.q_learning import QLearning

from dataclasses import dataclass
import random

import numpy as np

from copy import deepcopy

X = train_dataframe.drop(columns="APP").to_numpy()
y = train_dataframe["APP"].to_numpy()

# X_test = test_dataframe.drop(columns="APP").to_numpy()[:10000]
# y_test = test_dataframe["APP"].to_numpy()[:10000]

def create_test_data():
    grouped = test_dataframe.groupby('APP')

    X_arr = np.ndarray(shape = (10100, X.shape[1]))
    y_arr = np.ndarray(shape = (10100,))

    for index, i in enumerate(grouped):
        X_temp = i[1].drop(columns="APP").to_numpy()
        y_temp = i[1]["APP"].to_numpy()

        X_arr[index*100:(index*100)+100] = X_temp[:100]
        y_arr[index*100:(index*100)+100] = y_temp[:100]

    return (X_arr, y_arr)


@dataclass
class State_key:
    percent_of_class : int  # 1e-2, 1e-1. 5e-1, 1, more than 1
    predict_proba    : int  # 0-25, 25-50, 50-75, 75-100
    correct_predict  : bool # True or False

    def __hash__(self):
        return self.percent_of_class + \
               self.predict_proba * 5 + \
               int(self.correct_predict) * 10    
    
    def __eq__(self, other):
        if not isinstance(other, State_key) or self.__hash__() != other.__hash__():
            return False
        
        return True
        # return self.percent_of_class == other.percent_of_class and \
        #        self.predict_proba == other.predict_proba and \
        #        self.percent_used == other.percent_used
        
class Q(QLearning):
    def get_clf_prediction(self, index):
        proba = self.clf.predict_proba(X[index].reshape(1, -1))[0]
        hit = (self.clf.predict(X[index].reshape(1, -1)) == y[index])[0]

        return (proba, hit)

    def class_percent_into_discrete(self, percent):
        for i in range(len(self.CLASS_PERCENT_VALUES)):
            if percent < self.CLASS_PERCENT_VALUES[i]:
                return i
            
        return len(self.CLASS_PERCENT_VALUES)
    
    def predict_proba_into_discrete(self, proba):
        for i in range(len(self.PREDICT_PROBA_VALUES)):
            if proba < self.PREDICT_PROBA_VALUES[i]:
                return i
            
        return len(self.PREDICT_PROBA_VALUES)

    def percent_used_into_discrete(self, percent):
        for i in range(len(self.PERCENT_USED_VALUES)):
            if percent < self.PERCENT_USED_VALUES[i]:
                return i
            
        return len(self.PERCENT_USED_VALUES)

    def update_state(self, state_key, action_key):
        print(self.t, end = " ")
        print(state_key, end = " ")
        print(action_key)

        next_class = y[self.base_i + self.t + 1]

        if action_key == 1:
            self.class_amount[self.y_used[self.to_i - 1]] += 1
            self.used += 1

        class_percent = self.class_amount[next_class] / (self.used + self.base_samples)
        
        (proba, hit) = self.get_clf_prediction(self.base_i + self.t + 1)

        res_index = np.where(self.clf.classes_ == next_class)
        if len(res_index[0]):
            proba = self.predict_proba_into_discrete(proba[res_index[0][0]])
        else:
            proba = 0

        return State_key(self.class_percent_into_discrete(class_percent), 
                         proba,
                         hit)

    def initialize(self, cols, iters, already_used, nclasses):
        self.epsilon_greedy_rate = 0.9
        self.alpha_value = 0.1
        self.gamma_value = 0.9

        self.clf = RandomForestClassifier(max_depth=10)

        self.CLASS_PERCENT_VALUES = [0.0001, 0.01, 0.05, 0.1]
        self.PREDICT_PROBA_VALUES = [0.25, 0.50, 0.75]
        self.PERCENT_USED_VALUES  = [0.05, 0.08, 0.13, 0.21, 0.34, 0.89]

        self.used = 0
        self.base_samples = already_used
        self.base_i = already_used - 1
        self.to_i = already_used
        self.class_amount = {}

        for i in range(nclasses):
            self.class_amount[i] = 0

        self.X_used = np.ndarray(shape = (iters + already_used, cols))
        self.y_used = np.ndarray(shape = (iters + already_used,))
        self.last_f1 = 0
    
    def extract_possible_actions(self, state_key):
        return list({0, 1})

    def select_action(self, state_key, next_action_list):
        epsilon_greedy_flag = bool(np.random.binomial(n=1, p=self.epsilon_greedy_rate))

        if epsilon_greedy_flag is False:
            action_key = random.choice(next_action_list)
        else:
            action_key = self.predict_next_action(state_key, next_action_list)

        return action_key

    def train_clf(self, clf):
        clf.fit(self.X_used[:self.to_i], 
                self.y_used[:self.to_i])

    def test_acc(self):
        self.clf = RandomForestClassifier(max_depth=10)
        self.train_clf(self.clf)

        predict_arr = self.clf.predict(X_test)

        return f1_score(y_test, predict_arr, average="weighted")

    def observe_reward_value(self, state_key, action_key):
        # if action_key == 0:
        #     return 0

        self.X_used[self.to_i] = X[self.base_i + self.t]
        self.y_used[self.to_i] = y[self.base_i + self.t]

        self.to_i += 1

        cur_f1 = self.test_acc()
        reward = cur_f1 - self.last_f1

        percent_used = self.used / self.t

        if action_key == 0:

            reward *= percent_used - 0.1

            self.to_i -= 1
            reward = -reward
        else:
            reward *= -percent_used + 0.8

            self.last_f1 = cur_f1
        
        self.save_r_df(state_key, reward)

        return reward
    
    def learn(self, state_key, limit=1000, increased_rd = 1, decrease_alpha = 0):
        self.t = 1
        if decrease_alpha:
            self.alpha_value = 0.9

        while self.t <= limit:
            self.epsilon_greedy_rate = min(self.t / increased_rd, 0.9)
            self.alpha_value = max(self.alpha_value - decrease_alpha, 0.05)
            
            next_action_list = self.extract_possible_actions(state_key)
            if len(next_action_list):
                action_key = self.select_action(
                    state_key=state_key,
                    next_action_list=next_action_list
                )
                reward_value = self.observe_reward_value(state_key, action_key)

            if len(next_action_list):
                # Max-Q-Value in next action time.
                next_state_key = self.update_state(
                    state_key=state_key,
                    action_key=action_key
                )

                next_next_action_list = self.extract_possible_actions(next_state_key)
                next_action_key = self.predict_next_action(next_state_key, next_next_action_list)
                next_max_q = self.extract_q_df(next_state_key, next_action_key)

                # Update Q-Value.
                self.update_q(
                    state_key=state_key,
                    action_key=action_key,
                    reward_value=reward_value,
                    next_max_q=next_max_q
                )
                # Update State.
                state_key = next_state_key

            # Normalize.
            self.normalize_q_value()
            self.normalize_r_value()

            # Vis.
            self.visualize_learning_result(state_key)
            # Check.
            if self.check_the_end_flag(state_key) is True:
                break

            # Epsode.
            self.t += 1
    
(X_test, y_test) = create_test_data()

increased_rd = 100 # epsilon = min(self.t / increased_rd, 0.9)
decrease_alpha = 0.001
iters = 2000
base_samples_amount = 400

nclasses = len(train_dataframe.groupby('APP'))

q = Q()
q.t = 1
q.initialize(X.shape[1], iters, base_samples_amount, nclasses)

q.X_used[:base_samples_amount] = X[:base_samples_amount]
q.y_used[:base_samples_amount] = y[:base_samples_amount]
q.last_f1 = q.test_acc()


for i in range(base_samples_amount):
    q.class_amount[y[i]] += 1

state_key = q.update_state(State_key(0, 0, 0), 0)

q.learn(state_key, iters, increased_rd)
# Out:
# 1 State_key(percent_of_class=0, predict_proba=0, correct_predict=0) 0
# 0.0005466592989712193
# 1 State_key(percent_of_class=1, predict_proba=0, correct_predict=False) 0
# 0.0007247203605088529
# 2 State_key(percent_of_class=1, predict_proba=0, correct_predict=False) 1
# -0.0031273949650616043
# 3 State_key(percent_of_class=2, predict_proba=1, correct_predict=True) 0
# 0.0006863360790035265
# 4 State_key(percent_of_class=2, predict_proba=0, correct_predict=False) 1
# 0.00014740478384100975
# 5 State_key(percent_of_class=2, predict_proba=0, correct_predict=True) 0
# 0.0008333497694810743
# 6 State_key(percent_of_class=1, predict_proba=0, correct_predict=False) 0
# 0.0011529125409226579
# 7 State_key(percent_of_class=3, predict_proba=0, correct_predict=False) 0
# -0.004405905266101723
# 8 State_key(percent_of_class=3, predict_proba=0, correct_predict=False) 0
# 0.0010624869209063582
# 9 State_key(percent_of_class=2, predict_proba=1, correct_predict=True) 0
# -0.0003606259289886296
# 10 State_key(percent_of_class=1, predict_proba=0, correct_predict=False) 1
# 0.0004469057892957664
# 11 State_key(percent_of_class=1, predict_proba=0, correct_predict=False) 1
# -0.0031831303164075457
# 12 State_key(percent_of_class=2, predict_proba=1, correct_predict=True) 0
# -0.0010290428799361706
# 13 State_key(percent_of_class=2, predict_proba=1, correct_predict=True) 0
# 0.0008675939678733752
# 14 State_key(percent_of_class=1, predict_proba=0, correct_predict=False) 1
# -0.00015768470888216464
# 15 State_key(percent_of_class=3, predict_proba=1, correct_predict=True) 0
# -0.000591873127912149
# 16 State_key(percent_of_class=3, predict_proba=3, correct_predict=True) 1
# 0.00020600046656069822
# 17 State_key(percent_of_class=2, predict_proba=3, correct_predict=True) 0
# 0.0002797289971071611
# 18 State_key(percent_of_class=2, predict_proba=0, correct_predict=False) 1
# 0.00022905609463913984
# 19 State_key(percent_of_class=2, predict_proba=0, correct_predict=False) 0
# 0.001082185068469292
# 20 State_key(percent_of_class=3, predict_proba=0, correct_predict=True) 1
# -0.00046305437473555304
# 21 State_key(percent_of_class=2, predict_proba=0, correct_predict=False) 0
# 7.92528581806383e-05
# 22 State_key(percent_of_class=1, predict_proba=0, correct_predict=False) 1
# 0.0028112423386805283
# 23 State_key(percent_of_class=3, predict_proba=0, correct_predict=False) 1
# -0.002113146996402022
# 24 State_key(percent_of_class=2, predict_proba=0, correct_predict=False) 1
# -0.0028687639218759513
# 25 State_key(percent_of_class=3, predict_proba=0, correct_predict=False) 0
# 0.0009300577671104194
# 26 State_key(percent_of_class=2, predict_proba=1, correct_predict=True) 1
# -0.002317134454613774
# 27 State_key(percent_of_class=1, predict_proba=0, correct_predict=False) 1
# 0.0010607462527689139
# 28 State_key(percent_of_class=2, predict_proba=0, correct_predict=False) 1
# 0.0021698495791409493
# 29 State_key(percent_of_class=3, predict_proba=0, correct_predict=False) 1
# 0.0010028921967834227
# 30 State_key(percent_of_class=3, predict_proba=3, correct_predict=True) 1
# 0.0002504885966575764
# 31 State_key(percent_of_class=2, predict_proba=0, correct_predict=True) 0
# -0.003766807308088438
# 32 State_key(percent_of_class=3, predict_proba=0, correct_predict=False) 1
# 0.0026632069823563755
# 33 State_key(percent_of_class=2, predict_proba=3, correct_predict=True) 1
# -0.0006066354435438957
# 34 State_key(percent_of_class=0, predict_proba=0, correct_predict=False) 1
# 0.00062455369807596
# 35 State_key(percent_of_class=3, predict_proba=2, correct_predict=True) 1
# 0.0018022533870436916
# 36 State_key(percent_of_class=3, predict_proba=3, correct_predict=True) 0
# 0.0012151453472092628
# 37 State_key(percent_of_class=3, predict_proba=0, correct_predict=False) 1
# 0.0002207998512197935
# 38 State_key(percent_of_class=3, predict_proba=3, correct_predict=True) 0
# 0.0009369014578706812
# 39 State_key(percent_of_class=2, predict_proba=0, correct_predict=False) 0
# -0.001174152868171498
# 40 State_key(percent_of_class=3, predict_proba=2, correct_predict=True) 1
# -0.0007930945561884589
# 41 State_key(percent_of_class=2, predict_proba=0, correct_predict=False) 0
# 0.001329129216136977
# 42 State_key(percent_of_class=2, predict_proba=0, correct_predict=False) 1
# 9.163979711101826e-05
# 43 State_key(percent_of_class=3, predict_proba=1, correct_predict=True) 0
# 0.0027269281151191573
# 44 State_key(percent_of_class=2, predict_proba=0, correct_predict=True) 0
# 0.0010100898576631523
# 45 State_key(percent_of_class=2, predict_proba=0, correct_predict=True) 0
# -0.002249239866369068
# 46 State_key(percent_of_class=2, predict_proba=1, correct_predict=True) 1
# 0.0006079689429149141
# 47 State_key(percent_of_class=3, predict_proba=0, correct_predict=False) 0
# 0.00022784608709667254
# 48 State_key(percent_of_class=3, predict_proba=3, correct_predict=True) 1
# 0.001862187364951532
# 49 State_key(percent_of_class=2, predict_proba=1, correct_predict=False) 1
# -0.0019817141790032977
# 50 State_key(percent_of_class=1, predict_proba=2, correct_predict=True) 1
# -0.0021034228179680663
# 51 State_key(percent_of_class=2, predict_proba=1, correct_predict=True) 1
# 0.0014888237943897341
# 52 State_key(percent_of_class=2, predict_proba=1, correct_predict=True) 1
# -0.0006162528203476639
# 53 State_key(percent_of_class=3, predict_proba=2, correct_predict=True) 1
# -0.0006903480083048509
# 54 State_key(percent_of_class=1, predict_proba=0, correct_predict=False) 1
# 0.0019990983985655815
# 55 State_key(percent_of_class=3, predict_proba=0, correct_predict=False) 1
# -0.0018094634299075964
# 56 State_key(percent_of_class=3, predict_proba=1, correct_predict=True) 1
# 0.0024166888945231814
# 57 State_key(percent_of_class=1, predict_proba=0, correct_predict=False) 1
# -0.004557077706011234
# 58 State_key(percent_of_class=1, predict_proba=0, correct_predict=False) 1
# 0.005341884702536604
# 59 State_key(percent_of_class=1, predict_proba=0, correct_predict=False) 1
# -0.001022173431681395
# 60 State_key(percent_of_class=0, predict_proba=0, correct_predict=False) 0
# -0.00039991200023737196
# 61 State_key(percent_of_class=1, predict_proba=0, correct_predict=False) 1
# -0.0015282631823673007
# 62 State_key(percent_of_class=3, predict_proba=1, correct_predict=False) 1
# 0.00017471392631006476
# 63 State_key(percent_of_class=2, predict_proba=0, correct_predict=False) 0
# -0.0007763577909508985
# 64 State_key(percent_of_class=3, predict_proba=1, correct_predict=True) 1
# 0.0018097806706359743
# 65 State_key(percent_of_class=2, predict_proba=0, correct_predict=False) 1
# -0.002373155725080062
# 66 State_key(percent_of_class=2, predict_proba=1, correct_predict=True) 1
# 0.002572742219012791
# 67 State_key(percent_of_class=3, predict_proba=1, correct_predict=True) 1
# 0.0005726837573003075
# 68 State_key(percent_of_class=2, predict_proba=1, correct_predict=True) 1
# 0.0011121419774953018
# 69 State_key(percent_of_class=4, predict_proba=2, correct_predict=True) 0
# 0.0016677889043514894
# 70 State_key(percent_of_class=2, predict_proba=0, correct_predict=False) 1
# -9.76014736761183e-05
# 71 State_key(percent_of_class=1, predict_proba=0, correct_predict=False) 1
# -0.0020524346929602084
# 72 State_key(percent_of_class=2, predict_proba=0, correct_predict=False) 1
# 0.001101224166007896
# 73 State_key(percent_of_class=2, predict_proba=1, correct_predict=True) 1
# -0.0009854215296268931
# 74 State_key(percent_of_class=2, predict_proba=1, correct_predict=True) 1
# 0.0006201427934190989
# 75 State_key(percent_of_class=1, predict_proba=0, correct_predict=False) 1
# -0.00040620717330377157
# 76 State_key(percent_of_class=3, predict_proba=0, correct_predict=False) 1
# 0.0016353458637781981
# 77 State_key(percent_of_class=4, predict_proba=2, correct_predict=True) 1
# -0.0038400220423828496
# 78 State_key(percent_of_class=1, predict_proba=1, correct_predict=True) 1
# 0.0032818843352321156
# 79 State_key(percent_of_class=4, predict_proba=2, correct_predict=True) 1
# 0.00016064015598744362
# 80 State_key(percent_of_class=2, predict_proba=0, correct_predict=False) 0
# -0.002962688787661931
# 81 State_key(percent_of_class=1, predict_proba=0, correct_predict=False) 1
# 0.002140509463538635
# 82 State_key(percent_of_class=2, predict_proba=0, correct_predict=False) 1
# -0.0017201519131999521
# 83 State_key(percent_of_class=3, predict_proba=0, correct_predict=False) 1
# 0.0010629323248569262
# 84 State_key(percent_of_class=2, predict_proba=2, correct_predict=True) 1
# -0.0001195252936023691
# 85 State_key(percent_of_class=2, predict_proba=0, correct_predict=False) 1
# 0.0013404487859685996
# 86 State_key(percent_of_class=1, predict_proba=1, correct_predict=True) 1
# -0.0012788172557928572
# 87 State_key(percent_of_class=1, predict_proba=0, correct_predict=False) 1
# 0.00026992008144284665
# 88 State_key(percent_of_class=0, predict_proba=0, correct_predict=False) 1
# 0.0010307209879283632
# 89 State_key(percent_of_class=4, predict_proba=2, correct_predict=True) 1
# -0.0017490238953216984
# 90 State_key(percent_of_class=2, predict_proba=0, correct_predict=False) 1
# -0.0007449571259830765
# 91 State_key(percent_of_class=3, predict_proba=0, correct_predict=False) 0
# -0.000950458391991334
# 92 State_key(percent_of_class=1, predict_proba=0, correct_predict=False) 0
# 3.229634918993213e-05
# 93 State_key(percent_of_class=2, predict_proba=1, correct_predict=True) 0
# 0.002913224893191491
# 94 State_key(percent_of_class=2, predict_proba=1, correct_predict=True) 1
# -0.0003719570418280616
# 95 State_key(percent_of_class=3, predict_proba=1, correct_predict=True) 1
# -0.00024437166554916836
# 96 State_key(percent_of_class=2, predict_proba=0, correct_predict=False) 1
# 0.00039989338129103153
# 97 State_key(percent_of_class=2, predict_proba=2, correct_predict=True) 1
# 4.894848093335169e-05
# 98 State_key(percent_of_class=0, predict_proba=0, correct_predict=False) 0
# 0.0015680646263801369
# 99 State_key(percent_of_class=2, predict_proba=1, correct_predict=True) 0
# -0.0006572296810225246
# 100 State_key(percent_of_class=2, predict_proba=2, correct_predict=True) 1
# -0.0021911394528194316
# 101 State_key(percent_of_class=4, predict_proba=0, correct_predict=False) 1
# 0.0016800400691036018
# 102 State_key(percent_of_class=2, predict_proba=0, correct_predict=False) 1
# 0.0005722650668650643
# 103 State_key(percent_of_class=2, predict_proba=1, correct_predict=True) 1
# -0.0004724289876498969
# 104 State_key(percent_of_class=1, predict_proba=0, correct_predict=False) 1
# -0.0037541696122893272
# 105 State_key(percent_of_class=2, predict_proba=0, correct_predict=False) 1
# 0.005676421743778624
# 106 State_key(percent_of_class=3, predict_proba=0, correct_predict=False) 1
# 0.0001705319302245142
# 107 State_key(percent_of_class=2, predict_proba=1, correct_predict=True) 0
# 2.753812461093988e-05
# 108 State_key(percent_of_class=4, predict_proba=1, correct_predict=True) 1
# 0.0020975794009353917
# 109 State_key(percent_of_class=3, predict_proba=0, correct_predict=False) 1
# -0.005271865308937841
# 110 State_key(percent_of_class=2, predict_proba=0, correct_predict=True) 1
# 0.0022243033704581736
# 111 State_key(percent_of_class=3, predict_proba=2, correct_predict=True) 1
# -0.0015442891149999311
# 112 State_key(percent_of_class=3, predict_proba=0, correct_predict=True) 1
# 0.0015527219503654118
# 113 State_key(percent_of_class=2, predict_proba=0, correct_predict=False) 1
# -0.004352710793360036
# 114 State_key(percent_of_class=2, predict_proba=1, correct_predict=True) 1
# 0.0020658890207364894
# 115 State_key(percent_of_class=2, predict_proba=1, correct_predict=True) 1
# 0.003455132303651954
# 116 State_key(percent_of_class=1, predict_proba=0, correct_predict=True) 1
# -0.0011643919909509293
# 117 State_key(percent_of_class=2, predict_proba=1, correct_predict=True) 1
# -0.003957980226562004
# 118 State_key(percent_of_class=2, predict_proba=0, correct_predict=False) 1
# 0.009382123254684219
# 119 State_key(percent_of_class=3, predict_proba=0, correct_predict=True) 1
# -0.007478307038700216
# 120 State_key(percent_of_class=1, predict_proba=2, correct_predict=True) 1
# 0.0035310209968765125
# 121 State_key(percent_of_class=4, predict_proba=2, correct_predict=True) 1
# -0.0017423294872758873
# 122 State_key(percent_of_class=2, predict_proba=2, correct_predict=True) 1
# 0.0022675336989613115
# 123 State_key(percent_of_class=3, predict_proba=3, correct_predict=True) 1
# -5.385227040279651e-05
# 124 State_key(percent_of_class=3, predict_proba=0, correct_predict=False) 1
# 0.0017043186252184168
# 125 State_key(percent_of_class=2, predict_proba=0, correct_predict=False) 1
# -0.0029613853530227803
# 126 State_key(percent_of_class=2, predict_proba=1, correct_predict=True) 1
# -0.0006882367406258765
# 127 State_key(percent_of_class=3, predict_proba=0, correct_predict=False) 1
# -0.00010586682912707572
# 128 State_key(percent_of_class=2, predict_proba=0, correct_predict=False) 1
# -0.0007786359698567032
# 129 State_key(percent_of_class=4, predict_proba=2, correct_predict=True) 1
# 0.0016725519029841106
# 130 State_key(percent_of_class=2, predict_proba=0, correct_predict=False) 1
# 0.0009837964707084797
# 131 State_key(percent_of_class=1, predict_proba=3, correct_predict=True) 1
# 0.0014377945158176413
# 132 State_key(percent_of_class=2, predict_proba=1, correct_predict=True) 1
# -0.002279138364608132
# 133 State_key(percent_of_class=1, predict_proba=0, correct_predict=False) 1
# 0.0005416428632150038
# 134 State_key(percent_of_class=3, predict_proba=1, correct_predict=True) 1
# 7.567684665242186e-05
# 135 State_key(percent_of_class=3, predict_proba=1, correct_predict=True) 1
# -0.000541099097880951
# 136 State_key(percent_of_class=3, predict_proba=0, correct_predict=False) 1
# 0.00135876366326409
# 137 State_key(percent_of_class=2, predict_proba=3, correct_predict=True) 1
# -0.0016344115507288402
# 138 State_key(percent_of_class=2, predict_proba=2, correct_predict=True) 1
# 0.0028376851810389455
# 139 State_key(percent_of_class=2, predict_proba=0, correct_predict=False) 1
# -0.0026932102623344304
# 140 State_key(percent_of_class=1, predict_proba=0, correct_predict=False) 1
# 3.757576834384031e-05
# 141 State_key(percent_of_class=3, predict_proba=0, correct_predict=False) 0
# 0.0014471965943153322
# 142 State_key(percent_of_class=3, predict_proba=0, correct_predict=False) 1
# -0.0007066413834403613
# 143 State_key(percent_of_class=3, predict_proba=0, correct_predict=False) 1
# -6.583543715399124e-05
# 144 State_key(percent_of_class=1, predict_proba=0, correct_predict=False) 0
# 0.0020804144103220637
# 145 State_key(percent_of_class=3, predict_proba=0, correct_predict=True) 1
# -0.002458602948033113
# 146 State_key(percent_of_class=2, predict_proba=0, correct_predict=False) 1
# -0.0002866094375484999
# 147 State_key(percent_of_class=1, predict_proba=1, correct_predict=True) 1
# 0.001769895106183733
# 148 State_key(percent_of_class=1, predict_proba=0, correct_predict=False) 1
# -0.003038849279600553
# 149 State_key(percent_of_class=4, predict_proba=2, correct_predict=True) 1
# -0.00011221257654653105
# 150 State_key(percent_of_class=1, predict_proba=0, correct_predict=False) 0
# 0.0018457186439722263
# 151 State_key(percent_of_class=0, predict_proba=0, correct_predict=False) 1
# 0.00034196880022504774
# 152 State_key(percent_of_class=3, predict_proba=0, correct_predict=True) 1
# -0.002829118200604929
# 153 State_key(percent_of_class=3, predict_proba=3, correct_predict=True) 1
# 0.004306887246846939
# 154 State_key(percent_of_class=0, predict_proba=0, correct_predict=False) 1
# -0.00011123821406099971
# 155 State_key(percent_of_class=3, predict_proba=0, correct_predict=False) 1
# 0.002116680416989111
# 156 State_key(percent_of_class=1, predict_proba=0, correct_predict=False) 1
# -0.0023875144455792682
# 157 State_key(percent_of_class=3, predict_proba=0, correct_predict=False) 1
# 0.010659484827684149
# 158 State_key(percent_of_class=0, predict_proba=0, correct_predict=False) 1
# -0.0031976815488847154
# 159 State_key(percent_of_class=2, predict_proba=1, correct_predict=True) 1
# -0.00035597920820840367
# 160 State_key(percent_of_class=3, predict_proba=0, correct_predict=False) 1
# -0.0027885120021026327
# 161 State_key(percent_of_class=3, predict_proba=0, correct_predict=False) 1
# 0.0022895471490042467
# 162 State_key(percent_of_class=3, predict_proba=0, correct_predict=False) 1
# -0.0017147599644711734
# 163 State_key(percent_of_class=2, predict_proba=1, correct_predict=True) 1
# -0.000670060224921558
# 164 State_key(percent_of_class=2, predict_proba=1, correct_predict=True) 1
# -0.00018697505212171504
# 165 State_key(percent_of_class=3, predict_proba=0, correct_predict=False) 0
# 0.0002600539757062209
# 166 State_key(percent_of_class=3, predict_proba=0, correct_predict=False) 1
# -0.00033999524174022923
# 167 State_key(percent_of_class=2, predict_proba=3, correct_predict=True) 1
# 0.0024252994620225705
# 168 State_key(percent_of_class=3, predict_proba=0, correct_predict=False) 1
# 0.0012986740321341002
# 169 State_key(percent_of_class=3, predict_proba=0, correct_predict=False) 1
# -0.004580413189087974
# 170 State_key(percent_of_class=3, predict_proba=0, correct_predict=True) 1
# 0.0037092381900937937
# 171 State_key(percent_of_class=2, predict_proba=0, correct_predict=False) 1
# 0.0004122110739551904
# 172 State_key(percent_of_class=2, predict_proba=0, correct_predict=False) 1
# 1.2177695361254588e-05
# 173 State_key(percent_of_class=3, predict_proba=1, correct_predict=True) 0
# -0.001922439809732576
# 174 State_key(percent_of_class=2, predict_proba=2, correct_predict=True) 1
# 0.00011282010452850489
# 175 State_key(percent_of_class=3, predict_proba=1, correct_predict=True) 1
# -0.00083532072268324
# 176 State_key(percent_of_class=3, predict_proba=2, correct_predict=True) 1
# 0.0009262608881616125
# 177 State_key(percent_of_class=3, predict_proba=1, correct_predict=True) 1
# -0.0027924649297500228
# 178 State_key(percent_of_class=2, predict_proba=0, correct_predict=False) 1
# 0.0006929804924232629
# 179 State_key(percent_of_class=1, predict_proba=0, correct_predict=False) 1
# -0.001391391628932194
# 180 State_key(percent_of_class=3, predict_proba=2, correct_predict=True) 1
# 0.005371375019705238
# 181 State_key(percent_of_class=3, predict_proba=0, correct_predict=True) 1
# -0.0017262616536691145
# 182 State_key(percent_of_class=2, predict_proba=2, correct_predict=True) 1
# -0.004942704093815678
# 183 State_key(percent_of_class=2, predict_proba=0, correct_predict=False) 1
# -7.955688368654815e-05
# 184 State_key(percent_of_class=3, predict_proba=0, correct_predict=False) 0
# 0.002546182866074459
# 185 State_key(percent_of_class=0, predict_proba=0, correct_predict=False) 1
# 0.0073606837496438485
# 186 State_key(percent_of_class=2, predict_proba=3, correct_predict=True) 1
# -0.0020297370032581084
# 187 State_key(percent_of_class=3, predict_proba=0, correct_predict=False) 1
# 3.340544979753597e-05
# 188 State_key(percent_of_class=3, predict_proba=0, correct_predict=False) 0
# -0.003899333864717016
# 189 State_key(percent_of_class=2, predict_proba=2, correct_predict=True) 1
# -0.0016225817062880605
# 190 State_key(percent_of_class=2, predict_proba=0, correct_predict=False) 1
# 0.0012254861162102153
# 191 State_key(percent_of_class=1, predict_proba=0, correct_predict=False) 1
# 0.004765360919821255
# 192 State_key(percent_of_class=3, predict_proba=3, correct_predict=True) 1
# -0.0037901520000808986
# 193 State_key(percent_of_class=1, predict_proba=0, correct_predict=False) 1
# -4.805542561968229e-05
# 194 State_key(percent_of_class=1, predict_proba=0, correct_predict=False) 0
# -0.003473953279380739
# 195 State_key(percent_of_class=3, predict_proba=2, correct_predict=True) 1
# 0.0034334123709381715
# 196 State_key(percent_of_class=3, predict_proba=2, correct_predict=True) 1
# 5.0548282718720286e-05
# 197 State_key(percent_of_class=1, predict_proba=3, correct_predict=True) 1
# 0.002055931024751279
# 198 State_key(percent_of_class=3, predict_proba=3, correct_predict=True) 1
# -0.004243041183511533
# 199 State_key(percent_of_class=3, predict_proba=0, correct_predict=False) 1
# 0.001618049582148965
# 200 State_key(percent_of_class=2, predict_proba=2, correct_predict=True) 1
# 0.00043138073304501475
# 201 State_key(percent_of_class=4, predict_proba=2, correct_predict=True) 1
# 0.0035766542175569424
# 202 State_key(percent_of_class=2, predict_proba=0, correct_predict=True) 1
# -0.005552511313100107
# 203 State_key(percent_of_class=4, predict_proba=0, correct_predict=False) 1
# 0.00041733659029703757
# 204 State_key(percent_of_class=3, predict_proba=0, correct_predict=False) 1
# -0.0022281718844529125
# 205 State_key(percent_of_class=3, predict_proba=0, correct_predict=True) 1
# 0.0012164256051170994
# 206 State_key(percent_of_class=2, predict_proba=1, correct_predict=True) 1
# 0.00037890328910336683
# 207 State_key(percent_of_class=2, predict_proba=2, correct_predict=True) 1
# -0.0007102491178889378
# 208 State_key(percent_of_class=2, predict_proba=0, correct_predict=False) 1
# 0.0017785568033689984
# 209 State_key(percent_of_class=3, predict_proba=1, correct_predict=True) 1
# 0.0018274431878954642
# 210 State_key(percent_of_class=3, predict_proba=0, correct_predict=False) 1
# -0.0009029871052264605
# 211 State_key(percent_of_class=2, predict_proba=2, correct_predict=True) 1
# 0.0013370283699415532
# 212 State_key(percent_of_class=3, predict_proba=1, correct_predict=True) 1
# -6.865733896612282e-06
# 213 State_key(percent_of_class=3, predict_proba=3, correct_predict=True) 0
# -0.004923693127851677
# 214 State_key(percent_of_class=2, predict_proba=2, correct_predict=True) 1
# 0.007719925413706364
# 215 State_key(percent_of_class=3, predict_proba=0, correct_predict=False) 1
# -0.0006793975876191056
# 216 State_key(percent_of_class=1, predict_proba=0, correct_predict=False) 1
# -0.006022825534727051
# 217 State_key(percent_of_class=3, predict_proba=3, correct_predict=True) 1
# 0.001698928862086109
# 218 State_key(percent_of_class=2, predict_proba=0, correct_predict=False) 1
# 0.001973177125712691
# 219 State_key(percent_of_class=3, predict_proba=0, correct_predict=False) 1
# -0.0013549289457869599
# 220 State_key(percent_of_class=4, predict_proba=2, correct_predict=True) 1
# 0.0013279153081846371
# 221 State_key(percent_of_class=4, predict_proba=2, correct_predict=True) 1
# -0.0007349395366456772
# 222 State_key(percent_of_class=4, predict_proba=2, correct_predict=True) 1
# 0.004704704985968946
# 223 State_key(percent_of_class=2, predict_proba=0, correct_predict=False) 1
# -0.0030326089353099888
# 224 State_key(percent_of_class=3, predict_proba=3, correct_predict=True) 1
# -3.1448815862118506e-05
# 225 State_key(percent_of_class=3, predict_proba=0, correct_predict=False) 0
# -0.003454695353399956
# 226 State_key(percent_of_class=2, predict_proba=1, correct_predict=True) 1
# 0.0038782089682651076
# 227 State_key(percent_of_class=2, predict_proba=0, correct_predict=False) 1
# -0.0014781960602095138
# 228 State_key(percent_of_class=3, predict_proba=3, correct_predict=True) 1
# -0.0032316825749393176
# 229 State_key(percent_of_class=2, predict_proba=1, correct_predict=True) 1
# 0.004253238335620145
# 230 State_key(percent_of_class=1, predict_proba=0, correct_predict=False) 1
# -0.0014983446866406887
# 231 State_key(percent_of_class=3, predict_proba=0, correct_predict=False) 1
# 0.00024155065707788477
# 232 State_key(percent_of_class=2, predict_proba=3, correct_predict=True) 1
# 0.0013167009372401378
# 233 State_key(percent_of_class=2, predict_proba=1, correct_predict=False) 1
# 0.001438581363145741
# 234 State_key(percent_of_class=3, predict_proba=3, correct_predict=True) 1
# -0.004264618566452702
# 235 State_key(percent_of_class=2, predict_proba=2, correct_predict=True) 1
# -0.002614766656096152
# 236 State_key(percent_of_class=2, predict_proba=3, correct_predict=True) 1
# 0.005775648593783625
# 237 State_key(percent_of_class=2, predict_proba=1, correct_predict=True) 1
# 0.0011348301334187622
# 238 State_key(percent_of_class=2, predict_proba=1, correct_predict=True) 1
# -0.002825750035989298
# 239 State_key(percent_of_class=4, predict_proba=2, correct_predict=True) 1
# -0.0005438986301550444
# 240 State_key(percent_of_class=1, predict_proba=0, correct_predict=True) 1
# 0.0038452262464813156
# 241 State_key(percent_of_class=3, predict_proba=1, correct_predict=False) 1
# -0.005755600217958281
# 242 State_key(percent_of_class=1, predict_proba=0, correct_predict=False) 1
# 0.005263310899504855
# 243 State_key(percent_of_class=3, predict_proba=0, correct_predict=False) 1
# 0.0033028886481425946
# 244 State_key(percent_of_class=2, predict_proba=1, correct_predict=True) 1
# -0.0072420871546207315
# 245 State_key(percent_of_class=3, predict_proba=3, correct_predict=True) 1
# 0.0021353438939470787
# 246 State_key(percent_of_class=2, predict_proba=0, correct_predict=False) 1
# -0.0006326570984073101
# 247 State_key(percent_of_class=2, predict_proba=1, correct_predict=True) 1
# -0.00045007916122703
# 248 State_key(percent_of_class=3, predict_proba=0, correct_predict=False) 1
# 0.003935014164265306
# 249 State_key(percent_of_class=4, predict_proba=1, correct_predict=True) 1
# -0.0031208379989684457
# 250 State_key(percent_of_class=2, predict_proba=2, correct_predict=True) 1
# -0.0018937286850891056
# 251 State_key(percent_of_class=3, predict_proba=0, correct_predict=False) 1
# -0.0010991681976735218
# 252 State_key(percent_of_class=1, predict_proba=0, correct_predict=True) 1
# 0.004180908263316973
# 253 State_key(percent_of_class=1, predict_proba=0, correct_predict=False) 1
# 0.00014652941572683632
# 254 State_key(percent_of_class=2, predict_proba=1, correct_predict=True) 0
# -0.0010787016531532232
# 255 State_key(percent_of_class=3, predict_proba=0, correct_predict=False) 1
# 0.0021300472948742035
# 256 State_key(percent_of_class=3, predict_proba=1, correct_predict=True) 1
# -0.004086227163172394
# 257 State_key(percent_of_class=2, predict_proba=1, correct_predict=False) 1
# 0.0032177091002699248
# 258 State_key(percent_of_class=0, predict_proba=0, correct_predict=False) 1
# 8.50232974920378e-05
# 259 State_key(percent_of_class=2, predict_proba=0, correct_predict=True) 0
# -0.001614951767775927
# 260 State_key(percent_of_class=0, predict_proba=0, correct_predict=False) 1
# -0.0009137923800974129
# 261 State_key(percent_of_class=3, predict_proba=0, correct_predict=False) 1
# 0.004251506947325607
# 262 State_key(percent_of_class=2, predict_proba=1, correct_predict=True) 1
# -0.001743392243592131
# 263 State_key(percent_of_class=3, predict_proba=0, correct_predict=True) 1
# 0.0020233791791829663
# 264 State_key(percent_of_class=2, predict_proba=1, correct_predict=True) 1
# -0.004664331706728581
# 265 State_key(percent_of_class=2, predict_proba=0, correct_predict=False) 1
# 0.003285434242880246
# 266 State_key(percent_of_class=4, predict_proba=2, correct_predict=True) 1
# 0.001334591397751971
# 267 State_key(percent_of_class=2, predict_proba=0, correct_predict=False) 1
# -0.0013203296787955548
# 268 State_key(percent_of_class=1, predict_proba=0, correct_predict=False) 1
# 0.0012437604645757195
# 269 State_key(percent_of_class=2, predict_proba=0, correct_predict=True) 1
# -0.0015220872317304747
# 270 State_key(percent_of_class=3, predict_proba=3, correct_predict=True) 1
# -0.0004804331734148614
# 271 State_key(percent_of_class=3, predict_proba=2, correct_predict=True) 1
# 0.0013260970484920132
# 272 State_key(percent_of_class=4, predict_proba=2, correct_predict=True) 1
# -0.005560914566878169
# 273 State_key(percent_of_class=3, predict_proba=0, correct_predict=False) 1
# 0.0009764741372599992
# 274 State_key(percent_of_class=3, predict_proba=3, correct_predict=True) 1
# 0.00016228327966956565
# 275 State_key(percent_of_class=2, predict_proba=2, correct_predict=True) 0
# 0.0025158798190425577
# 276 State_key(percent_of_class=2, predict_proba=1, correct_predict=True) 1
# -0.0005513045199500763
# 277 State_key(percent_of_class=3, predict_proba=0, correct_predict=False) 1
# 0.00245731138526584
# 278 State_key(percent_of_class=2, predict_proba=0, correct_predict=True) 1
# -0.003839998904535361
# 279 State_key(percent_of_class=3, predict_proba=0, correct_predict=False) 1
# 0.003973226014936353
# 280 State_key(percent_of_class=2, predict_proba=1, correct_predict=False) 1
# -0.0004890013454704284
# 281 State_key(percent_of_class=4, predict_proba=1, correct_predict=True) 1
# 0.0005564807516992085
# 282 State_key(percent_of_class=2, predict_proba=0, correct_predict=False) 1
# -0.0070696409040617485
# 283 State_key(percent_of_class=4, predict_proba=2, correct_predict=True) 1
# 0.004598278339277359
# 284 State_key(percent_of_class=4, predict_proba=3, correct_predict=True) 1
# 0.0002596938091650116
# 285 State_key(percent_of_class=2, predict_proba=3, correct_predict=True) 1
# 0.001598632008795943
# 286 State_key(percent_of_class=3, predict_proba=3, correct_predict=True) 1
# -0.003031636729674991
# 287 State_key(percent_of_class=2, predict_proba=0, correct_predict=False) 1
# 0.0042072006946098145
# 288 State_key(percent_of_class=2, predict_proba=0, correct_predict=False) 1
# -0.0009128552136744156
# 289 State_key(percent_of_class=2, predict_proba=0, correct_predict=True) 1
# -0.0030874185416022164
# 290 State_key(percent_of_class=0, predict_proba=0, correct_predict=False) 1
# 0.0026097995616505827
# 291 State_key(percent_of_class=2, predict_proba=0, correct_predict=True) 1
# 0.0015936475040536494
# 292 State_key(percent_of_class=3, predict_proba=1, correct_predict=True) 1
# -0.0037093849289864702
# 293 State_key(percent_of_class=4, predict_proba=1, correct_predict=True) 1
# -0.0005541345632553544
# 294 State_key(percent_of_class=3, predict_proba=0, correct_predict=True) 1
# 0.002693850858765457
# 295 State_key(percent_of_class=2, predict_proba=0, correct_predict=False) 1
# -0.003262231187954128
# 296 State_key(percent_of_class=3, predict_proba=1, correct_predict=False) 1
# 0.00027424909371437037
# 297 State_key(percent_of_class=2, predict_proba=0, correct_predict=False) 1
# 0.00012056414274385715
# 298 State_key(percent_of_class=3, predict_proba=1, correct_predict=True) 0
# -0.0020872137533693644
# 299 State_key(percent_of_class=3, predict_proba=1, correct_predict=True) 1
# 0.0004226688948991364
# 300 State_key(percent_of_class=2, predict_proba=1, correct_predict=True) 1
# 0.003059227691571985
# 301 State_key(percent_of_class=2, predict_proba=0, correct_predict=False) 1
# 4.285987144540664e-05
# 302 State_key(percent_of_class=3, predict_proba=3, correct_predict=True) 1
# 0.0029525492389043846
# 303 State_key(percent_of_class=2, predict_proba=1, correct_predict=True) 1
# -0.006544723555672185
# 304 State_key(percent_of_class=3, predict_proba=0, correct_predict=False) 1
# 0.005973290242830597
# 305 State_key(percent_of_class=3, predict_proba=0, correct_predict=False) 1
# -0.003121410916524189
# 306 State_key(percent_of_class=3, predict_proba=0, correct_predict=False) 1
# -0.0011606448093058924
# 307 State_key(percent_of_class=1, predict_proba=0, correct_predict=False) 1
# -0.00029925920739614736
# 308 State_key(percent_of_class=4, predict_proba=0, correct_predict=False) 1
# 7.942407596240045e-05
# 309 State_key(percent_of_class=3, predict_proba=3, correct_predict=True) 1
# 0.0003675613712410226
# 310 State_key(percent_of_class=2, predict_proba=3, correct_predict=True) 1
# 0.00446426448424044
# 311 State_key(percent_of_class=3, predict_proba=1, correct_predict=False) 1
# -0.0018908258283412446
# 312 State_key(percent_of_class=4, predict_proba=2, correct_predict=True) 1
# -0.00024452045129325463
# 313 State_key(percent_of_class=2, predict_proba=1, correct_predict=True) 1
# 0.004086562112660716
# 314 State_key(percent_of_class=2, predict_proba=0, correct_predict=False) 1
# -0.002566710973342063
# 315 State_key(percent_of_class=2, predict_proba=1, correct_predict=True) 1
# -0.000620224867429581
# 316 State_key(percent_of_class=1, predict_proba=0, correct_predict=False) 1
# -0.0017262092849731892
# 317 State_key(percent_of_class=1, predict_proba=0, correct_predict=False) 1
# 0.0037924109236232516
# 318 State_key(percent_of_class=3, predict_proba=1, correct_predict=False) 1
# 0.0021708044441819904
# 319 State_key(percent_of_class=4, predict_proba=3, correct_predict=True) 1
# -0.004815698811289008
# 320 State_key(percent_of_class=2, predict_proba=0, correct_predict=False) 1
# 0.0036421041137131285
# 321 State_key(percent_of_class=3, predict_proba=3, correct_predict=True) 1
# -0.003624787952178194
# 322 State_key(percent_of_class=1, predict_proba=0, correct_predict=False) 1
# 0.004207144555979744
# 323 State_key(percent_of_class=2, predict_proba=0, correct_predict=True) 1
# -0.004510822368631278
# 324 State_key(percent_of_class=2, predict_proba=2, correct_predict=True) 1
# -0.0013409445913299858
# 325 State_key(percent_of_class=3, predict_proba=0, correct_predict=False) 1
# 0.002980736269902822
# 326 State_key(percent_of_class=2, predict_proba=1, correct_predict=True) 1
# 0.0006976065415745455
# 327 State_key(percent_of_class=2, predict_proba=1, correct_predict=True) 1
# -0.0076052168608226915
# 328 State_key(percent_of_class=3, predict_proba=1, correct_predict=True) 1
# 0.00028549996438038597
# 329 State_key(percent_of_class=2, predict_proba=0, correct_predict=False) 0
# 0.006452593979370916
# 330 State_key(percent_of_class=3, predict_proba=1, correct_predict=True) 1
# 0.0006989903450604152
# 331 State_key(percent_of_class=2, predict_proba=2, correct_predict=True) 1
# 0.0012410451827842622
# 332 State_key(percent_of_class=2, predict_proba=0, correct_predict=False) 1
# 0.00045917711240180305
# 333 State_key(percent_of_class=2, predict_proba=2, correct_predict=True) 1
# -0.0018795048553117255
# 334 State_key(percent_of_class=2, predict_proba=0, correct_predict=False) 1
# -0.002531874172685529
# 335 State_key(percent_of_class=3, predict_proba=3, correct_predict=True) 1
# -0.0008832513824722159
# 336 State_key(percent_of_class=2, predict_proba=0, correct_predict=True) 1
# 0.0031474183243456414
# 337 State_key(percent_of_class=2, predict_proba=1, correct_predict=True) 1
# -0.002402733839472513
# 338 State_key(percent_of_class=2, predict_proba=3, correct_predict=True) 1
# 0.002716592728617181
# 339 State_key(percent_of_class=1, predict_proba=0, correct_predict=False) 1
# -0.001605343522626513
# 340 State_key(percent_of_class=3, predict_proba=1, correct_predict=True) 1
# 0.0030715827408431913
# 341 State_key(percent_of_class=2, predict_proba=0, correct_predict=False) 1
# -0.0060351995673883245
# 342 State_key(percent_of_class=4, predict_proba=3, correct_predict=True) 1
# 0.0033126107518555103
# 343 State_key(percent_of_class=4, predict_proba=3, correct_predict=True) 1
# -0.0032388267306320074
# 344 State_key(percent_of_class=1, predict_proba=0, correct_predict=False) 1
# 0.005877747404315916
# 345 State_key(percent_of_class=4, predict_proba=2, correct_predict=True) 1
# -0.0013067686414381925
# 346 State_key(percent_of_class=4, predict_proba=3, correct_predict=True) 1
# -0.0013325110263377631
# 347 State_key(percent_of_class=1, predict_proba=1, correct_predict=True) 1
# 0.0001478876053552378
# 348 State_key(percent_of_class=2, predict_proba=2, correct_predict=True) 1
# -0.0012190442527481645
# 349 State_key(percent_of_class=4, predict_proba=2, correct_predict=True) 1
# 0.005395950520662338
# 350 State_key(percent_of_class=3, predict_proba=3, correct_predict=True) 1
# -0.003487598635938749
# 351 State_key(percent_of_class=2, predict_proba=0, correct_predict=False) 1
# -0.0012184011683745329
# 352 State_key(percent_of_class=4, predict_proba=2, correct_predict=True) 1
# 0.0026916098623271144
# 353 State_key(percent_of_class=2, predict_proba=2, correct_predict=True) 1
# -0.001691808611887037
# 354 State_key(percent_of_class=3, predict_proba=0, correct_predict=True) 1
# -0.005931489940777356
# 355 State_key(percent_of_class=3, predict_proba=0, correct_predict=True) 1
# -5.7312212103133894e-05
# 356 State_key(percent_of_class=3, predict_proba=3, correct_predict=True) 0
# 0.0004375012797628503
# 357 State_key(percent_of_class=1, predict_proba=0, correct_predict=False) 0
# 0.007544772906435036
# 358 State_key(percent_of_class=2, predict_proba=3, correct_predict=True) 1
# -0.002403833213606807
# 359 State_key(percent_of_class=2, predict_proba=1, correct_predict=True) 1
# -0.001994664745797446
# 360 State_key(percent_of_class=2, predict_proba=0, correct_predict=True) 1
# -0.000663381336383173
# 361 State_key(percent_of_class=2, predict_proba=3, correct_predict=True) 1
# 0.003108524726366066
# 362 State_key(percent_of_class=3, predict_proba=0, correct_predict=False) 1
# -0.00018395364987392694
# 363 State_key(percent_of_class=2, predict_proba=0, correct_predict=False) 0
# -0.0016228918644621143
# 364 State_key(percent_of_class=3, predict_proba=3, correct_predict=True) 1
# 0.0038760162195615832
# 365 State_key(percent_of_class=2, predict_proba=1, correct_predict=True) 1
# -0.0025763344676864594
# 366 State_key(percent_of_class=3, predict_proba=3, correct_predict=True) 1
# -0.00040004376853093485
# 367 State_key(percent_of_class=4, predict_proba=2, correct_predict=True) 1
# -0.0040504981696120905
# 368 State_key(percent_of_class=2, predict_proba=0, correct_predict=False) 1
# 0.003056916668229233
# 369 State_key(percent_of_class=3, predict_proba=3, correct_predict=True) 1
# -0.00013265798611759058
# 370 State_key(percent_of_class=1, predict_proba=0, correct_predict=False) 1
# -0.0014024556953480584
# 371 State_key(percent_of_class=3, predict_proba=1, correct_predict=True) 1
# 0.00034568828025046105
# 372 State_key(percent_of_class=3, predict_proba=1, correct_predict=True) 0
# 0.004819657079078975
# 373 State_key(percent_of_class=4, predict_proba=2, correct_predict=True) 1
# -0.003345679882797496
# 374 State_key(percent_of_class=1, predict_proba=0, correct_predict=False) 1
# -0.0006393776085703676
# 375 State_key(percent_of_class=2, predict_proba=0, correct_predict=True) 1
# -0.0011944389697516428
# 376 State_key(percent_of_class=3, predict_proba=2, correct_predict=True) 1
# 0.004890222481041192
# 377 State_key(percent_of_class=3, predict_proba=0, correct_predict=True) 1
# -0.0009886504151919073
# 378 State_key(percent_of_class=2, predict_proba=1, correct_predict=True) 1
# 0.0007472639313542162
# 379 State_key(percent_of_class=1, predict_proba=1, correct_predict=True) 1
# -0.0014714627080546342
# 380 State_key(percent_of_class=2, predict_proba=1, correct_predict=True) 1
# 0.0007063181845754449
# 381 State_key(percent_of_class=1, predict_proba=0, correct_predict=False) 1
# 0.0009232852808349318
# 382 State_key(percent_of_class=3, predict_proba=0, correct_predict=False) 1
# 0.0025873768892551033
# 383 State_key(percent_of_class=2, predict_proba=1, correct_predict=False) 1
# -0.0019571115220455735
# 384 State_key(percent_of_class=2, predict_proba=0, correct_predict=False) 1
# 0.006282023664644095
# 385 State_key(percent_of_class=2, predict_proba=1, correct_predict=True) 1
# -0.00866968554789814
# 386 State_key(percent_of_class=4, predict_proba=3, correct_predict=True) 1
# 0.0013185540399751798
# 387 State_key(percent_of_class=4, predict_proba=3, correct_predict=True) 1
# 0.001704455963907714
# 388 State_key(percent_of_class=1, predict_proba=0, correct_predict=False) 1
# 0.0014595251885871625
# 389 State_key(percent_of_class=1, predict_proba=0, correct_predict=False) 1
# -0.004891768945158499
# 390 State_key(percent_of_class=1, predict_proba=1, correct_predict=True) 1
# 0.005989442396872672
# 391 State_key(percent_of_class=2, predict_proba=1, correct_predict=True) 1
# -0.0037832256034494877
# 392 State_key(percent_of_class=2, predict_proba=0, correct_predict=False) 1
# -0.0008619493723139609
# 393 State_key(percent_of_class=3, predict_proba=0, correct_predict=False) 1
# 0.00430632150358178
# 394 State_key(percent_of_class=1, predict_proba=0, correct_predict=False) 1
# -0.0017648786009327206
# 395 State_key(percent_of_class=1, predict_proba=0, correct_predict=False) 1
# 0.0015985191023624
# 396 State_key(percent_of_class=2, predict_proba=0, correct_predict=True) 1
# -0.0014386499679603898
# 397 State_key(percent_of_class=1, predict_proba=1, correct_predict=True) 1
# 0.0027742415190087216
# 398 State_key(percent_of_class=3, predict_proba=1, correct_predict=True) 1
# -0.0034348045044819355
# 399 State_key(percent_of_class=1, predict_proba=0, correct_predict=False) 1
# -0.00024175572010356433
# 400 State_key(percent_of_class=3, predict_proba=0, correct_predict=False) 1
# 0.002064823933020332
# 401 State_key(percent_of_class=2, predict_proba=0, correct_predict=False) 1
# -0.0034202002045065306
# 402 State_key(percent_of_class=4, predict_proba=2, correct_predict=True) 1
# 0.0010138085636279166
# 403 State_key(percent_of_class=3, predict_proba=1, correct_predict=False) 1
# 7.83696425334167e-05
# 404 State_key(percent_of_class=2, predict_proba=0, correct_predict=False) 1
# 0.0029248626606741546
# 405 State_key(percent_of_class=1, predict_proba=0, correct_predict=False) 1
# 0.0014457296438684084
# 406 State_key(percent_of_class=1, predict_proba=0, correct_predict=False) 1
# -0.004227086742016357
# 407 State_key(percent_of_class=2, predict_proba=2, correct_predict=True) 1
# 3.66406145112451e-05
# 408 State_key(percent_of_class=2, predict_proba=2, correct_predict=True) 0
# 0.002246091047401514
# 409 State_key(percent_of_class=2, predict_proba=3, correct_predict=True) 1
# -0.0007073655190658081
# 410 State_key(percent_of_class=3, predict_proba=0, correct_predict=False) 1
# 0.002951889089167041
# 411 State_key(percent_of_class=2, predict_proba=0, correct_predict=False) 1
# -0.005753544984081671
# 412 State_key(percent_of_class=3, predict_proba=3, correct_predict=True) 1
# 0.0031230168108376142
# 413 State_key(percent_of_class=3, predict_proba=3, correct_predict=True) 1
# 0.0009180826833430027
# 414 State_key(percent_of_class=3, predict_proba=3, correct_predict=True) 1
# -0.0026706950112525838
# 415 State_key(percent_of_class=2, predict_proba=1, correct_predict=True) 1
# 0.0019128891296222856
# 416 State_key(percent_of_class=4, predict_proba=2, correct_predict=True) 1
# -0.0015468044335148331
# 417 State_key(percent_of_class=1, predict_proba=0, correct_predict=False) 1
# 0.002745012665332738
# 418 State_key(percent_of_class=2, predict_proba=2, correct_predict=True) 1
# -0.0014831410726735314
# 419 State_key(percent_of_class=1, predict_proba=1, correct_predict=True) 1
# 0.0036246261076317296
# 420 State_key(percent_of_class=1, predict_proba=2, correct_predict=True) 1
# -0.004732567470086065
# 421 State_key(percent_of_class=3, predict_proba=1, correct_predict=True) 1
# 0.00040461545362985556
# 422 State_key(percent_of_class=1, predict_proba=0, correct_predict=False) 1
# 0.0019890943348857605
# 423 State_key(percent_of_class=2, predict_proba=3, correct_predict=True) 1
# 0.0020129483669249215
# 424 State_key(percent_of_class=2, predict_proba=1, correct_predict=True) 1
# -0.0004400459072780979
# 425 State_key(percent_of_class=3, predict_proba=0, correct_predict=False) 1
# -0.004713254529517076
# 426 State_key(percent_of_class=2, predict_proba=1, correct_predict=True) 1
# 0.006352600197643927
# 427 State_key(percent_of_class=2, predict_proba=2, correct_predict=True) 1
# -0.002689960797315981
# 428 State_key(percent_of_class=1, predict_proba=0, correct_predict=False) 1
# -2.808524572378071e-05
# 429 State_key(percent_of_class=2, predict_proba=0, correct_predict=False) 0
# -0.004685867038032119
# 430 State_key(percent_of_class=1, predict_proba=0, correct_predict=False) 1
# -0.0014070292508029593
# 431 State_key(percent_of_class=3, predict_proba=2, correct_predict=True) 1
# 0.0039655771512279794
# 432 State_key(percent_of_class=4, predict_proba=2, correct_predict=True) 1
# 0.0013435536444403708
# 433 State_key(percent_of_class=2, predict_proba=1, correct_predict=False) 1
# 0.0008668503220558802
# 434 State_key(percent_of_class=2, predict_proba=2, correct_predict=True) 1
# -0.0034556717737595243
# 435 State_key(percent_of_class=3, predict_proba=1, correct_predict=True) 1
# 0.003324030647255332
# 436 State_key(percent_of_class=2, predict_proba=2, correct_predict=True) 1
# -0.0015102482396117528
# 437 State_key(percent_of_class=1, predict_proba=0, correct_predict=False) 1
# -0.002055113134380499
# 438 State_key(percent_of_class=3, predict_proba=1, correct_predict=True) 1
# 0.003359500486389077
# 439 State_key(percent_of_class=3, predict_proba=3, correct_predict=True) 1
# 0.0020091574098118183
# 440 State_key(percent_of_class=2, predict_proba=1, correct_predict=True) 1
# -0.001744271631298304
# 441 State_key(percent_of_class=2, predict_proba=0, correct_predict=False) 1
# 5.471069974643809e-05
# 442 State_key(percent_of_class=4, predict_proba=1, correct_predict=True) 1
# 0.00138130963362195
# 443 State_key(percent_of_class=3, predict_proba=2, correct_predict=True) 1
# -0.005597858069780007
# 444 State_key(percent_of_class=3, predict_proba=0, correct_predict=True) 1
# 0.0037064374382569155
# 445 State_key(percent_of_class=3, predict_proba=2, correct_predict=True) 1
# 0.00032414741983140407
# 446 State_key(percent_of_class=2, predict_proba=0, correct_predict=False) 1
# -0.00247779426576953
# 447 State_key(percent_of_class=2, predict_proba=0, correct_predict=False) 1
# 0.003973802243351465
# 448 State_key(percent_of_class=3, predict_proba=2, correct_predict=True) 1
# -0.002156756212527384
# 449 State_key(percent_of_class=2, predict_proba=3, correct_predict=True) 1
# 0.0007454217671333931
# 450 State_key(percent_of_class=2, predict_proba=0, correct_predict=False) 1
# 0.0010988450372836761
# 451 State_key(percent_of_class=2, predict_proba=1, correct_predict=True) 1
# -0.009300776250728435
# 452 State_key(percent_of_class=2, predict_proba=0, correct_predict=True) 1
# 0.009027059651373388
# 453 State_key(percent_of_class=2, predict_proba=1, correct_predict=True) 1
# 0.00147583854387611
# 454 State_key(percent_of_class=1, predict_proba=0, correct_predict=True) 1
# 0.0009523533432313808
# 455 State_key(percent_of_class=1, predict_proba=0, correct_predict=False) 1
# -0.000751290591589424
# 456 State_key(percent_of_class=2, predict_proba=1, correct_predict=True) 1
# 0.0002864194596083438
# 457 State_key(percent_of_class=2, predict_proba=0, correct_predict=False) 1
# 0.0042480275979141745
# 458 State_key(percent_of_class=2, predict_proba=1, correct_predict=True) 1
# -0.00677959515353022
# 459 State_key(percent_of_class=2, predict_proba=3, correct_predict=True) 1
# 0.0015455532872777995
# 460 State_key(percent_of_class=2, predict_proba=0, correct_predict=True) 1
# 0.0019590011541437092
# 461 State_key(percent_of_class=3, predict_proba=1, correct_predict=True) 1
# -0.0009284813761579482
# 462 State_key(percent_of_class=3, predict_proba=1, correct_predict=True) 1
# -0.0005942457428722765
# 463 State_key(percent_of_class=1, predict_proba=0, correct_predict=True) 1
# -0.003854506221106756
# 464 State_key(percent_of_class=2, predict_proba=0, correct_predict=False) 1
# -0.00012986325619172484
# 465 State_key(percent_of_class=2, predict_proba=0, correct_predict=False) 1
# 0.000147818452978678
# 466 State_key(percent_of_class=2, predict_proba=1, correct_predict=True) 0
# 0.004987389891274541
# 467 State_key(percent_of_class=2, predict_proba=2, correct_predict=True) 1
# -0.001242064160054244
# 468 State_key(percent_of_class=1, predict_proba=0, correct_predict=False) 1
# 0.000278142787179807
# 469 State_key(percent_of_class=1, predict_proba=0, correct_predict=False) 1
# 0.0038153597938324585
# 470 State_key(percent_of_class=2, predict_proba=0, correct_predict=False) 1
# -0.004178358096633376
# 471 State_key(percent_of_class=2, predict_proba=2, correct_predict=True) 1
# -0.0018579581855490256
# 472 State_key(percent_of_class=2, predict_proba=1, correct_predict=True) 1
# 0.00029953698803214876
# 473 State_key(percent_of_class=0, predict_proba=0, correct_predict=False) 1
# 0.0003689071171768073
# 474 State_key(percent_of_class=1, predict_proba=0, correct_predict=False) 0
# 0.0006767945783229751
# 475 State_key(percent_of_class=1, predict_proba=0, correct_predict=False) 1
# 0.00018740815593978934
# 476 State_key(percent_of_class=2, predict_proba=2, correct_predict=True) 1
# -8.96478460996619e-05
# 477 State_key(percent_of_class=3, predict_proba=1, correct_predict=True) 1
# 0.0019481978782938194
# 478 State_key(percent_of_class=2, predict_proba=3, correct_predict=True) 1
# 0.0036696656228496693
# 479 State_key(percent_of_class=2, predict_proba=0, correct_predict=False) 1
# -0.005835567105710393
# 480 State_key(percent_of_class=1, predict_proba=0, correct_predict=False) 1
# 0.006728018590299344
# 481 State_key(percent_of_class=1, predict_proba=0, correct_predict=False) 1
# -0.005901556460813369
# 482 State_key(percent_of_class=1, predict_proba=0, correct_predict=True) 1
# 0.004594195942043798
# 483 State_key(percent_of_class=2, predict_proba=1, correct_predict=False) 1
# -0.0008472918131265013
# 484 State_key(percent_of_class=3, predict_proba=0, correct_predict=False) 1
# -0.003484612619552229
# 485 State_key(percent_of_class=2, predict_proba=1, correct_predict=True) 1
# -0.0011501957038330597
# 486 State_key(percent_of_class=1, predict_proba=0, correct_predict=False) 1
# 0.0038797501592425275
# 487 State_key(percent_of_class=1, predict_proba=0, correct_predict=False) 1
# -0.004306553113250992
# 488 State_key(percent_of_class=3, predict_proba=3, correct_predict=True) 1
# 0.005410653297337489
# 489 State_key(percent_of_class=2, predict_proba=0, correct_predict=False) 1
# -0.0020105530791849897
# 490 State_key(percent_of_class=4, predict_proba=2, correct_predict=True) 1
# 0.00262979750048835
# 491 State_key(percent_of_class=3, predict_proba=3, correct_predict=True) 1
# -0.0055668189582381115
# ...
# -0.0053166317362528005
# 523 State_key(percent_of_class=1, predict_proba=1, correct_predict=True) 1
# 0.006109919908122482
# 524 State_key(percent_of_class=2, predict_proba=3, correct_predict=True) 1
# 0.0010752949368532739
# 525 State_key(percent_of_class=3, predict_proba=1, correct_predict=True) 1
# -0.003514424848510855
# 526 State_key(percent_of_class=2, predict_proba=0, correct_predict=False) 1
# 0.0019625741899697846
# 527 State_key(percent_of_class=3, predict_proba=1, correct_predict=True) 1
# -0.002883658896339959
# 528 State_key(percent_of_class=1, predict_proba=0, correct_predict=False) 1
# 0.003675488264800701
# 529 State_key(percent_of_class=2, predict_proba=0, correct_predict=False) 1
# -0.0008654518678365089
# 530 State_key(percent_of_class=1, predict_proba=0, correct_predict=True) 1
# 0.0014469916003666296
# 531 State_key(percent_of_class=2, predict_proba=1, correct_predict=True) 1
# 0.0026696003258777946
# 532 State_key(percent_of_class=2, predict_proba=2, correct_predict=True) 1
# -0.008170083317461848
# 533 State_key(percent_of_class=3, predict_proba=3, correct_predict=True) 1
# 0.004181745001063021
# 534 State_key(percent_of_class=3, predict_proba=0, correct_predict=False) 1
# 0.002026112148032547
# 535 State_key(percent_of_class=3, predict_proba=1, correct_predict=True) 1
# -0.0013176460836565786
# 536 State_key(percent_of_class=3, predict_proba=0, correct_predict=False) 1
# -0.00065633868889511
# 537 State_key(percent_of_class=1, predict_proba=0, correct_predict=True) 0
# 0.0017391072377441774
# 538 State_key(percent_of_class=3, predict_proba=0, correct_predict=False) 1
# -0.0030120825126014883
# 539 State_key(percent_of_class=1, predict_proba=0, correct_predict=False) 1
# -0.0018968216368277745
# 540 State_key(percent_of_class=3, predict_proba=0, correct_predict=False) 1
# 0.006045808648605972
# 541 State_key(percent_of_class=2, predict_proba=2, correct_predict=True) 1
# -0.003602917724859586
# 542 State_key(percent_of_class=3, predict_proba=3, correct_predict=True) 1
# 0.0004393442055522402
# 543 State_key(percent_of_class=2, predict_proba=1, correct_predict=True) 1
# -0.002109806677206071
# 544 State_key(percent_of_class=3, predict_proba=1, correct_predict=True) 1
# -0.0005965246087057438
# 545 State_key(percent_of_class=2, predict_proba=0, correct_predict=False) 0
# -0.0013858244407540959
# 546 State_key(percent_of_class=2, predict_proba=1, correct_predict=True) 1
# 0.005995604750660112
# 547 State_key(percent_of_class=3, predict_proba=3, correct_predict=True) 1
# -0.0015665521246444874
# 548 State_key(percent_of_class=3, predict_proba=2, correct_predict=True) 1
# -0.003479225221219973
# 549 State_key(percent_of_class=3, predict_proba=0, correct_predict=False) 1
# 0.00023615093636264662
# 550 State_key(percent_of_class=3, predict_proba=2, correct_predict=True) 1
# 0.0005053949855035592
# 551 State_key(percent_of_class=2, predict_proba=2, correct_predict=True) 1
# 0.0021374762870142094
# 552 State_key(percent_of_class=1, predict_proba=0, correct_predict=False) 1
# 0.0002478514994048628
# 553 State_key(percent_of_class=3, predict_proba=3, correct_predict=True) 0
# 0.00037602168574776905
# 554 State_key(percent_of_class=3, predict_proba=2, correct_predict=True) 1
# 0.0012583600538417577
# 555 State_key(percent_of_class=3, predict_proba=3, correct_predict=True) 1
# -0.002142014905685699
# 556 State_key(percent_of_class=2, predict_proba=0, correct_predict=False) 1
# 0.0027594027687058457
# 557 State_key(percent_of_class=3, predict_proba=0, correct_predict=False) 1
# 0.0003150861300348825
# 558 State_key(percent_of_class=1, predict_proba=0, correct_predict=False) 1
# -0.008475794318501751
# 559 State_key(percent_of_class=0, predict_proba=0, correct_predict=False) 1
# 0.004673004611353651
# 560 State_key(percent_of_class=3, predict_proba=0, correct_predict=False) 1
# 0.0029339590258692875
# 561 State_key(percent_of_class=3, predict_proba=1, correct_predict=True) 1
# -0.0057914525500731675
# 562 State_key(percent_of_class=3, predict_proba=2, correct_predict=True) 1
# 0.005566602033905157
# 563 State_key(percent_of_class=3, predict_proba=1, correct_predict=True) 1
# -0.004020643116065764
# 564 State_key(percent_of_class=2, predict_proba=0, correct_predict=False) 1
# 0.0022471913634129668
# 565 State_key(percent_of_class=2, predict_proba=0, correct_predict=False) 1
# -0.00030424461390461617
# 566 State_key(percent_of_class=3, predict_proba=1, correct_predict=True) 0
# 0.002074503633621196
# 567 State_key(percent_of_class=1, predict_proba=1, correct_predict=True) 1
# -0.0020337676084730494
# 568 State_key(percent_of_class=3, predict_proba=0, correct_predict=False) 1
# -0.0007668621967088448
# 569 State_key(percent_of_class=3, predict_proba=1, correct_predict=True) 1
# -0.00305607067128611
# 570 State_key(percent_of_class=2, predict_proba=0, correct_predict=False) 1
# 0.0015672584926330784
# 571 State_key(percent_of_class=3, predict_proba=1, correct_predict=True) 1
# 0.004376549167373972
# 572 State_key(percent_of_class=3, predict_proba=1, correct_predict=True) 1
# -1.918074046174026e-05
# 573 State_key(percent_of_class=3, predict_proba=0, correct_predict=False) 1
# -0.00039602368064275615
# 574 State_key(percent_of_class=3, predict_proba=0, correct_predict=False) 1
# -0.005852818731602472
# 575 State_key(percent_of_class=2, predict_proba=0, correct_predict=False) 1
# 0.0061666319794793385
# 576 State_key(percent_of_class=3, predict_proba=2, correct_predict=True) 1
# -0.005335765497378065
# 577 State_key(percent_of_class=2, predict_proba=3, correct_predict=True) 1
# -0.0003225529975667905
# 578 State_key(percent_of_class=3, predict_proba=0, correct_predict=False) 1
# -0.00029988587223734654
# 579 State_key(percent_of_class=2, predict_proba=0, correct_predict=False) 1
# 0.0032061321469061383
# 580 State_key(percent_of_class=3, predict_proba=2, correct_predict=True) 1
# 0.0011887869434373112
# 581 State_key(percent_of_class=3, predict_proba=0, correct_predict=False) 1
# -0.0036025308930224477
# 582 State_key(percent_of_class=2, predict_proba=0, correct_predict=True) 1
# 0.00019467118566090665
# 583 State_key(percent_of_class=3, predict_proba=2, correct_predict=True) 0
# 0.0016477319559347417
# 584 State_key(percent_of_class=2, predict_proba=0, correct_predict=False) 1
# -0.002500419241448242
# 585 State_key(percent_of_class=2, predict_proba=0, correct_predict=False) 1
# 0.00020086048630315066
# 586 State_key(percent_of_class=3, predict_proba=0, correct_predict=False) 1
# 0.002337366507998123
# 587 State_key(percent_of_class=1, predict_proba=0, correct_predict=False) 1
# -0.0009039378019475681
# 588 State_key(percent_of_class=4, predict_proba=2, correct_predict=True) 1
# -0.00041698928307512556
# 589 State_key(percent_of_class=3, predict_proba=0, correct_predict=True) 1
# 0.0014836123151261871
# 590 State_key(percent_of_class=2, predict_proba=0, correct_predict=True) 1
# -0.002908325617108578
# 591 State_key(percent_of_class=3, predict_proba=0, correct_predict=False) 1
# -0.0017119900378048684
# 592 State_key(percent_of_class=3, predict_proba=3, correct_predict=True) 1
# 0.00030679328421335215
# 593 State_key(percent_of_class=3, predict_proba=2, correct_predict=True) 0
# 0.002224902076579995
# 594 State_key(percent_of_class=3, predict_proba=3, correct_predict=True) 1
# 0.004067700231799965
# 595 State_key(percent_of_class=4, predict_proba=3, correct_predict=True) 1
# -0.0007624976407261963
# 596 State_key(percent_of_class=2, predict_proba=1, correct_predict=True) 1
# -0.0006934817310643782
# 597 State_key(percent_of_class=3, predict_proba=1, correct_predict=False) 1
# 0.00109988355678909
# 598 State_key(percent_of_class=2, predict_proba=0, correct_predict=False) 1
# -0.0007444714851407348
# 599 State_key(percent_of_class=1, predict_proba=0, correct_predict=False) 1
# -0.0024478713868022113
# 600 State_key(percent_of_class=1, predict_proba=0, correct_predict=False) 1
# 0.0009534369322142111
# 601 State_key(percent_of_class=2, predict_proba=1, correct_predict=False) 1
# -0.0002380159482921511
# 602 State_key(percent_of_class=3, predict_proba=0, correct_predict=False) 1
# -0.00014831336190078897
# 603 State_key(percent_of_class=1, predict_proba=0, correct_predict=False) 0
# -0.0022604781800015235
# 604 State_key(percent_of_class=3, predict_proba=0, correct_predict=False) 1
# -0.00017861189644759323
# 605 State_key(percent_of_class=2, predict_proba=0, correct_predict=False) 1
# 0.003931238946574784
# 606 State_key(percent_of_class=2, predict_proba=0, correct_predict=False) 1
# 0.002930351654529137
# 607 State_key(percent_of_class=2, predict_proba=0, correct_predict=False) 1
# -0.0036565397387484768
# 608 State_key(percent_of_class=1, predict_proba=0, correct_predict=False) 1
# -0.0031895868663401467
# 609 State_key(percent_of_class=4, predict_proba=3, correct_predict=True) 1
# 0.0010672978420531234
# 610 State_key(percent_of_class=2, predict_proba=0, correct_predict=False) 1
# 0.0018796010267472093
# 611 State_key(percent_of_class=3, predict_proba=0, correct_predict=True) 1
# -0.0005582925447638117
# 612 State_key(percent_of_class=4, predict_proba=3, correct_predict=True) 1
# 0.0002054516864907959
# 613 State_key(percent_of_class=3, predict_proba=0, correct_predict=False) 1
# 0.0007981576624175738
# 614 State_key(percent_of_class=3, predict_proba=0, correct_predict=False) 1
# -0.001555362015064391
# 615 State_key(percent_of_class=3, predict_proba=2, correct_predict=True) 1
# 0.0006185510573570029
# 616 State_key(percent_of_class=4, predict_proba=3, correct_predict=True) 1
# -0.0009892586797216874
# 617 State_key(percent_of_class=3, predict_proba=3, correct_predict=True) 1
# 0.001494324382616141
# 618 State_key(percent_of_class=3, predict_proba=0, correct_predict=False) 1
# 0.0020835217042856147
# 619 State_key(percent_of_class=3, predict_proba=0, correct_predict=False) 1
# -0.004794238464434496
# 620 State_key(percent_of_class=2, predict_proba=0, correct_predict=True) 1
# 0.002508385654798682
# 621 State_key(percent_of_class=4, predict_proba=0, correct_predict=False) 1
# -0.0019324735064515785
# 622 State_key(percent_of_class=3, predict_proba=3, correct_predict=True) 1
# 0.0023615883900975627
# 623 State_key(percent_of_class=3, predict_proba=3, correct_predict=True) 1
# -0.0007212236466023189
# 624 State_key(percent_of_class=1, predict_proba=0, correct_predict=True) 0
# -0.00011671982930842187
# 625 State_key(percent_of_class=3, predict_proba=1, correct_predict=True) 0
# -0.0043469117148681475
# 626 State_key(percent_of_class=4, predict_proba=2, correct_predict=True) 1
# 0.004342738635960389
# 627 State_key(percent_of_class=2, predict_proba=2, correct_predict=True) 1
# -0.0018309018097371792
# 628 State_key(percent_of_class=1, predict_proba=0, correct_predict=False) 1
# 0.0015432523993782765
# 629 State_key(percent_of_class=3, predict_proba=3, correct_predict=True) 1
# 0.001095675913749627
# 630 State_key(percent_of_class=3, predict_proba=0, correct_predict=False) 1
# -0.004495430386925252
# 631 State_key(percent_of_class=2, predict_proba=3, correct_predict=True) 1
# -0.0011402561742642316
# 632 State_key(percent_of_class=4, predict_proba=2, correct_predict=True) 1
# 0.002458224723687841
# 633 State_key(percent_of_class=3, predict_proba=1, correct_predict=True) 1
# 0.002862872265836152
# 634 State_key(percent_of_class=1, predict_proba=0, correct_predict=False) 1
# -0.003961760634926498
# 635 State_key(percent_of_class=1, predict_proba=0, correct_predict=True) 1
# 0.00039763632461264654
# 636 State_key(percent_of_class=1, predict_proba=0, correct_predict=True) 1
# -0.004305053192449777
# 637 State_key(percent_of_class=2, predict_proba=2, correct_predict=True) 1
# 0.005039348986928989
# 638 State_key(percent_of_class=1, predict_proba=0, correct_predict=True) 1
# -0.00034391534161929744
# 639 State_key(percent_of_class=4, predict_proba=1, correct_predict=True) 1
# -9.365385531646939e-05
# 640 State_key(percent_of_class=3, predict_proba=2, correct_predict=True) 1
# 0.0010381477332203457
# 641 State_key(percent_of_class=2, predict_proba=3, correct_predict=True) 1
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[15], line 289
#     285     q.class_amount[y[i]] += 1
#     287 state_key = q.update_state(State_key(0, 0, 0), 0)
# --> 289 q.learn(state_key, iters, increased_rd)
#
# Cell In[15], line 230, in Q.learn(self, state_key, limit, increased_rd, decrease_alpha)
#     225 if len(next_action_list):
#     226     action_key = self.select_action(
#     227         state_key=state_key,
#     228         next_action_list=next_action_list
#     229     )
# --> 230     reward_value = self.observe_reward_value(state_key, action_key)
#     232 if len(next_action_list):
#     233     # Max-Q-Value in next action time.
#     234     next_state_key = self.update_state(
#     235         state_key=state_key,
#     236         action_key=action_key
#     237     )
#
# Cell In[15], line 193, in Q.observe_reward_value(self, state_key, action_key)
#     189 self.y_used[self.to_i] = y[self.base_i + self.t]
#     191 self.to_i += 1
# --> 193 cur_f1 = self.test_acc()
#     194 reward = cur_f1 - self.last_f1
#     196 percent_used = self.used / self.t
#
# Cell In[15], line 180, in Q.test_acc(self)
#     177 self.clf = RandomForestClassifier(max_depth=10)
#     178 self.train_clf(self.clf)
# --> 180 predict_arr = self.clf.predict(X_test)
#     182 return f1_score(y_test, predict_arr, average="weighted")
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/ensemble/_forest.py:821, in ForestClassifier.predict(self, X)
#     800 def predict(self, X):
#     801     """
#     802     Predict class for X.
#     803
#    (...)
#     819         The predicted classes.
#     820     """
# --> 821     proba = self.predict_proba(X)
#     823     if self.n_outputs_ == 1:
#     824         return self.classes_.take(np.argmax(proba, axis=1), axis=0)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/ensemble/_forest.py:874, in ForestClassifier.predict_proba(self, X)
#     869 all_proba = [
#     870     np.zeros((X.shape[0], j), dtype=np.float64)
#     871     for j in np.atleast_1d(self.n_classes_)
#     872 ]
#     873 lock = threading.Lock()
# --> 874 Parallel(n_jobs=n_jobs, verbose=self.verbose, require="sharedmem")(
#     875     delayed(_accumulate_prediction)(e.predict_proba, X, all_proba, lock)
#     876     for e in self.estimators_
#     877 )
#     879 for proba in all_proba:
#     880     proba /= len(self.estimators_)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/joblib/parallel.py:1918, in Parallel.__call__(self, iterable)
#    1916     output = self._get_sequential_output(iterable)
#    1917     next(output)
# -> 1918     return output if self.return_generator else list(output)
#    1920 # Let's create an ID that uniquely identifies the current call. If the
#    1921 # call is interrupted early and that the same instance is immediately
#    1922 # re-used, this id will be used to prevent workers that were
#    1923 # concurrently finalizing a task from the previous call to run the
#    1924 # callback.
#    1925 with self._lock:
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/joblib/parallel.py:1847, in Parallel._get_sequential_output(self, iterable)
#    1845 self.n_dispatched_batches += 1
#    1846 self.n_dispatched_tasks += 1
# -> 1847 res = func(*args, **kwargs)
#    1848 self.n_completed_tasks += 1
#    1849 self.print_progress()
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/utils/fixes.py:117, in _FuncWrapper.__call__(self, *args, **kwargs)
#     115 def __call__(self, *args, **kwargs):
#     116     with config_context(**self.config):
# --> 117         return self.function(*args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/ensemble/_forest.py:652, in _accumulate_prediction(predict, X, out, lock)
#     645 """
#     646 This is a utility function for joblib's Parallel.
#     647
#     648 It can't go locally in ForestClassifier or ForestRegressor, because joblib
#     649 complains that it cannot pickle it when placed there.
#     650 """
#     651 prediction = predict(X, check_input=False)
# --> 652 with lock:
#     653     if len(out) == 1:
#     654         out[0] += prediction
#
# KeyboardInterrupt:

# %%
X_test = test_dataframe.drop(columns="APP").to_numpy()[:100000]
y_test = test_dataframe["APP"].to_numpy()[:100000]

print(q.to_i)

clf = RandomForestClassifier()
clf.fit(q.X_used[:q.to_i], q.y_used[:q.to_i])

predict_arr = clf.predict(X_test)

print(f"q_learning_acc: {accuracy_score(y_test, predict_arr):.4f}")


clf = RandomForestClassifier()
clf.fit(X[:iters + base_samples_amount], y[:iters + base_samples_amount])

predict_arr = clf.predict(X_test)

print(f"q_learning_acc: {accuracy_score(y_test, predict_arr):.4f}")

q_df = q.q_df
q_df = q_df.sort_values(by=["q_value"], ascending=False)
print(q_df.head())
# Out:
# 976
# q_learning_acc: 0.4803
# q_learning_acc: 0.5437
#                                            state_key  action_key   q_value
# 0  State_key(percent_of_class=1, predict_proba=2,...           1  0.000819
# 0  State_key(percent_of_class=1, predict_proba=3,...           1  0.000789
# 0  State_key(percent_of_class=1, predict_proba=1,...           1  0.000771
# 0  State_key(percent_of_class=2, predict_proba=0,...           0  0.000636
# 0  State_key(percent_of_class=3, predict_proba=0,...           0  0.000618

# %%
print(q_df.shape)

for index, row in q_df.iterrows():
    print(f"Row {index}: {row.to_dict()}")
# Out:
# (35, 3)
# Row 0: {'state_key': State_key(percent_of_class=1, predict_proba=2, correct_predict=True), 'action_key': 1, 'q_value': 0.0008188299594172905}
# Row 0: {'state_key': State_key(percent_of_class=1, predict_proba=3, correct_predict=True), 'action_key': 1, 'q_value': 0.0007890320796824258}
# Row 0: {'state_key': State_key(percent_of_class=1, predict_proba=1, correct_predict=True), 'action_key': 1, 'q_value': 0.0007710628802873285}
# Row 0: {'state_key': State_key(percent_of_class=2, predict_proba=0, correct_predict=True), 'action_key': 0, 'q_value': 0.0006363271328668374}
# Row 0: {'state_key': State_key(percent_of_class=3, predict_proba=0, correct_predict=False), 'action_key': 0, 'q_value': 0.0006178267247697296}
# Row 0: {'state_key': State_key(percent_of_class=4, predict_proba=2, correct_predict=True), 'action_key': 0, 'q_value': 0.0005893137357581213}
# Row 0: {'state_key': State_key(percent_of_class=2, predict_proba=1, correct_predict=True), 'action_key': 1, 'q_value': 0.00043631970481285034}
# Row 0: {'state_key': State_key(percent_of_class=3, predict_proba=3, correct_predict=True), 'action_key': 0, 'q_value': 0.00039444144930768984}
# Row 0: {'state_key': State_key(percent_of_class=2, predict_proba=1, correct_predict=True), 'action_key': 0, 'q_value': 0.0003863163593172328}
# Row 0: {'state_key': State_key(percent_of_class=0, predict_proba=0, correct_predict=False), 'action_key': 0, 'q_value': 0.0003783636703046404}
# Row 0: {'state_key': State_key(percent_of_class=2, predict_proba=2, correct_predict=True), 'action_key': 0, 'q_value': 0.00037689649204454995}
# Row 0: {'state_key': State_key(percent_of_class=3, predict_proba=1, correct_predict=False), 'action_key': 1, 'q_value': 0.000362608334658284}
# Row 0: {'state_key': State_key(percent_of_class=3, predict_proba=2, correct_predict=True), 'action_key': 0, 'q_value': 0.00035758370145698475}
# Row 0: {'state_key': State_key(percent_of_class=2, predict_proba=0, correct_predict=False), 'action_key': 0, 'q_value': 0.0003436078768561035}
# Row 0: {'state_key': State_key(percent_of_class=1, predict_proba=0, correct_predict=False), 'action_key': 0, 'q_value': 0.0003257975229481391}
# Row 0: {'state_key': State_key(percent_of_class=3, predict_proba=0, correct_predict=False), 'action_key': 1, 'q_value': 0.0003235682870852188}
# Row 0: {'state_key': State_key(percent_of_class=1, predict_proba=0, correct_predict=False), 'action_key': 1, 'q_value': 0.0002925222112253513}
# Row 0: {'state_key': State_key(percent_of_class=3, predict_proba=0, correct_predict=True), 'action_key': 1, 'q_value': 0.00024684280813375945}
# Row 0: {'state_key': State_key(percent_of_class=1, predict_proba=0, correct_predict=True), 'action_key': 0, 'q_value': 0.0002435107039783169}
# Row 0: {'state_key': State_key(percent_of_class=2, predict_proba=1, correct_predict=False), 'action_key': 1, 'q_value': 0.0002350804866617408}
# Row 0: {'state_key': State_key(percent_of_class=3, predict_proba=1, correct_predict=True), 'action_key': 0, 'q_value': 0.00022990294863486658}
# Row 0: {'state_key': State_key(percent_of_class=3, predict_proba=3, correct_predict=True), 'action_key': 1, 'q_value': 0.0002161623188992486}
# Row 0: {'state_key': State_key(percent_of_class=4, predict_proba=0, correct_predict=False), 'action_key': 1, 'q_value': 0.00020836129438979087}
# Row 0: {'state_key': State_key(percent_of_class=4, predict_proba=3, correct_predict=True), 'action_key': 1, 'q_value': 0.00018715235066619899}
# Row 0: {'state_key': State_key(percent_of_class=2, predict_proba=3, correct_predict=True), 'action_key': 1, 'q_value': 7.373447127857847e-05}
# Row 0: {'state_key': State_key(percent_of_class=2, predict_proba=0, correct_predict=False), 'action_key': 1, 'q_value': 5.9477480261655084e-05}
# Row 0: {'state_key': State_key(percent_of_class=0, predict_proba=0, correct_predict=False), 'action_key': 1, 'q_value': 3.4794657155879185e-05}
# Row 0: {'state_key': State_key(percent_of_class=1, predict_proba=0, correct_predict=True), 'action_key': 1, 'q_value': 1.3293399524251515e-05}
# Row 0: {'state_key': State_key(percent_of_class=3, predict_proba=1, correct_predict=True), 'action_key': 1, 'q_value': 6.297964284581923e-06}
# Row 0: {'state_key': State_key(percent_of_class=4, predict_proba=1, correct_predict=True), 'action_key': 1, 'q_value': -2.1231068632920745e-05}
# Row 0: {'state_key': State_key(percent_of_class=3, predict_proba=2, correct_predict=True), 'action_key': 1, 'q_value': -3.038414347823848e-05}
# Row 0: {'state_key': State_key(percent_of_class=2, predict_proba=0, correct_predict=True), 'action_key': 1, 'q_value': -4.290633443442156e-05}
# Row 0: {'state_key': State_key(percent_of_class=4, predict_proba=2, correct_predict=True), 'action_key': 1, 'q_value': -0.0002419439475598002}
# Row 0: {'state_key': State_key(percent_of_class=2, predict_proba=3, correct_predict=True), 'action_key': 0, 'q_value': -0.00040037144762363196}
# Row 0: {'state_key': State_key(percent_of_class=2, predict_proba=2, correct_predict=True), 'action_key': 1, 'q_value': -0.0004955974739077246}

# %%
from cesnet_datazoo.datasets import CESNET_QUIC22
from cesnet_datazoo.config import DatasetConfig, AppSelection, ValidationApproach

dataset = CESNET_QUIC22("~/datasets/CESNET-QUIC22/", size="XS")

common_params = {
    "dataset": dataset,
    "apps_selection": AppSelection.ALL_KNOWN,
    "train_period_name": "W-2022-44",
    "val_approach": ValidationApproach.SPLIT_FROM_TRAIN,
    "train_val_split_fraction": 0.2,
    "use_packet_histograms": True,
}
dataset_config = DatasetConfig(**common_params)
dataset.set_dataset_config_and_initialize(dataset_config)
train_dataframe = dataset.get_train_df(flatten_ppi=True)
val_dataframe = dataset.get_val_df(flatten_ppi=True)
test_dataframe = dataset.get_test_df(flatten_ppi=True)
# Out:
# Loading data from dataloader
# 100%|██████████| 8162/8162 [00:12<00:00, 651.95it/s]
# Loading data from dataloader
# 100%|██████████| 192/192 [00:06<00:00, 30.58it/s]
# Loading data from dataloader
# 100%|██████████| 1247/1247 [00:13<00:00, 95.23it/s]

# %%
from sklearn.neighbors import LocalOutlierFactor
import matplotlib.pyplot as plt
import numpy as np

X = train_dataframe.drop(columns="APP").to_numpy()[:30000]

clf = LocalOutlierFactor(n_jobs=-1, n_neighbors=100)
clf.fit(X)
arr = clf.negative_outlier_factor_
arr = arr * -1
arr = np.sort(arr)

thresholds = np.quantile(arr, np.linspace(0, 1, 5 + 1))[1:]
print(thresholds)

index = 0
for i, el in enumerate(arr):
    if el > thresholds[index]:
        index += 1
        print(i)

fig, ax = plt.subplots()

# ax.set_yscale('log')

# [3.00017625e-01 1.00131171e+00 1.04109173e+00 1.13963060e+00
#  1.42144246e+00 1.71395547e+11]

plt.plot(arr, label="outliers")
plt.xlabel("n")
plt.ylabel("outlier score")
plt.legend()
plt.show()

# q.y = train_dataframe["APP"].to_numpy()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[49], line 8
#       5 X = train_dataframe.drop(columns="APP").to_numpy()[:30000]
#       7 clf = LocalOutlierFactor(n_jobs=-1, n_neighbors=100)
# ----> 8 clf.fit(X)
#       9 arr = clf.negative_outlier_factor_
#      10 arr = arr * -1
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/neighbors/_lof.py:290, in LocalOutlierFactor.fit(self, X, y)
#     282     warnings.warn(
#     283         "n_neighbors (%s) is greater than the "
#     284         "total number of samples (%s). n_neighbors "
#     285         "will be set to (n_samples - 1) for estimation."
#     286         % (self.n_neighbors, n_samples)
#     287     )
#     288 self.n_neighbors_ = max(1, min(self.n_neighbors, n_samples - 1))
# --> 290 self._distances_fit_X_, _neighbors_indices_fit_X_ = self.kneighbors(
# ...
